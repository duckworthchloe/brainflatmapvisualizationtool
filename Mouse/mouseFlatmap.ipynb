# %% [markdown]
# 1. Play this cell first.

# %%
# %%capture
# !sudo apt install libcairo2-dev pkg-config python3-dev
# !pip install svglib
# !pip install PyPDF2
import defusedxml.ElementTree as ET
import pandas as pd
import numpy as np
from svglib.svglib import svg2rlg
from reportlab.graphics import renderPDF
import PyPDF2
# installs and imports all required libraries and packages

# %% [markdown]
# 2. Play this cell and follow the instructions in the output to give Google permission to change the flatmap file's colors with this code.
#
# ---

# %%
# %%capture
from google.colab import drive
drive.mount('/content/drive/')
# %cd drive/My Drive/brainflatmapvisualizationtool-main/Mouse
# Mounts the drive and connects the correct file pathway

# %% [markdown]
# 3. Play this cell and when it's done loading, you can view your updated flatmaps in the folder.

# %%
inputtedData=pd.read_excel('mouseInputtedData.xlsx',"Processed Sheet")
# inputs data chosen to represent activation in heat map
leftColors=['#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999']
rightColors=['#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999']
# creates a list of grey colors with an index for each brain region represented

color0='#66CCFF'
# creates zero value
color1='#FFE1E1'
# creates very weak value
color2='#FFC0C0'
# creates weak value
color3='#FF9191'
# creates weak-moderate value
color4='#FF0000'
# creates moderate value
color5='#C80200'
# creates moderate-strong value
color6='#960200'
# creates strong value
color7='#710200'
# creates very strong value
color8='#FF00FF'
# creates site of interest value

leftData=inputtedData['Left Bucketed Value']
leftData=leftData.tolist()
rightData=inputtedData['Right Bucketed Value']
rightData=rightData.tolist()
left=[leftData,leftColors]
right=[rightData,rightColors]
sides=[left,right]
# creates arrays for left and right bucketed values and lists with each brain region's bucketed value and attributed color

for side in sides:
  for indexData in range(0,382):
    if side[0][indexData]=="SITE":
        side[1][indexData]=color8
        # assigns color8 to injection site regions
    elif side[0][indexData]==0:
        side[1][indexData]=color0
        # assigns color0 to inputtedData values equal to 0
    elif side[0][indexData]==1:
        side[1][indexData]=color1
        # assigns color1 to inputtedData values less than or equal to the second value of range
    elif side[0][indexData]==2:
        side[1][indexData]=color2
        # assigns color2 to inputtedData values less than or equal to the third value of range
    elif side[0][indexData]==3:
        side[1][indexData]=color3
        # assigns color3 to inputtedData values less than or equal to the fourth value of range
    elif side[0][indexData]==4:
        side[1][indexData]=color4
        # assigns color4 to inputtedData values less than or equal to the fifth value of range
    elif side[0][indexData]==5:
        side[1][indexData]=color5
        # assigns color5 to inputtedData values less than or equal to the sixth value of range
    elif side[0][indexData]==6:
        side[1][indexData]=color6
        # assigns color6 to inputtedData values less than or equal to the seventh value of range
    elif side[0][indexData]==7:
        side[1][indexData]=color7
        # assigns color7 to inputtedData values less than or equal to the eighth value of range

tree=ET.parse("MsBF1regions.svg")
# Load SVG as XML file

root=tree.getroot()
# Get tree's root

block=root.find('{http://www.w3.org/2000/svg}path[@class="st0"]')
block.set('style','fill:{}'.format(rightColors[0]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st1"]')
block.set('style','fill:{}'.format(rightColors[1]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st2"]')
block.set('style','fill:{}'.format(rightColors[2]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st3"]')
block.set('style','fill:{}'.format(rightColors[3]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st4"]')
block.set('style','fill:{}'.format(rightColors[4]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st5"]')
block.set('style','fill:{}'.format(rightColors[5]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st6"]')
block.set('style','fill:{}'.format(rightColors[6]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st7"]')
block.set('style','fill:{}'.format(rightColors[7]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st8"]')
block.set('style','fill:{}'.format(rightColors[8]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st9"]')
block.set('style','fill:{}'.format(rightColors[9]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st10"]')
block.set('style','fill:{}'.format(rightColors[10]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st11"]')
block.set('style','fill:{}'.format(rightColors[11]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st12"]')
block.set('style','fill:{}'.format(rightColors[12]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st13"]')
block.set('style','fill:{}'.format(rightColors[13]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st14"]')
block.set('style','fill:{}'.format(rightColors[14]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st15"]')
block.set('style','fill:{}'.format(rightColors[15]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st16"]')
block.set('style','fill:{}'.format(rightColors[16]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st17"]')
block.set('style','fill:{}'.format(rightColors[17]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st18"]')
block.set('style','fill:{}'.format(rightColors[18]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st19"]')
block.set('style','fill:{}'.format(rightColors[19]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st20"]')
block.set('style','fill:{}'.format(rightColors[20]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st21"]')
block.set('style','fill:{}'.format(rightColors[21]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st22"]')
block.set('style','fill:{}'.format(rightColors[22]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st23"]')
block.set('style','fill:{}'.format(rightColors[23]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st24"]')
block.set('style','fill:{}'.format(rightColors[24]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st25"]')
block.set('style','fill:{}'.format(rightColors[25]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st26"]')
block.set('style','fill:{}'.format(rightColors[26]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st27"]')
block.set('style','fill:{}'.format(rightColors[27]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st28"]')
block.set('style','fill:{}'.format(rightColors[28]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st29"]')
block.set('style','fill:{}'.format(rightColors[29]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st30"]')
block.set('style','fill:{}'.format(rightColors[30]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st31"]')
block.set('style','fill:{}'.format(rightColors[31]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st32"]')
block.set('style','fill:{}'.format(rightColors[32]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st33"]')
block.set('style','fill:{}'.format(rightColors[33]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st34"]')
block.set('style','fill:{}'.format(rightColors[34]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st35"]')
block.set('style','fill:{}'.format(rightColors[35]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st36"]')
block.set('style','fill:{}'.format(rightColors[36]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st37"]')
block.set('style','fill:{}'.format(rightColors[37]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st38"]')
block.set('style','fill:{}'.format(rightColors[38]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st39"]')
block.set('style','fill:{}'.format(rightColors[39]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st40"]')
block.set('style','fill:{}'.format(rightColors[40]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st41"]')
block.set('style','fill:{}'.format(rightColors[41]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st42"]')
block.set('style','fill:{}'.format(rightColors[42]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st43"]')
block.set('style','fill:{}'.format(rightColors[43]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st44"]')
block.set('style','fill:{}'.format(rightColors[44]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st45"]')
block.set('style','fill:{}'.format(rightColors[45]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st46"]')
block.set('style','fill:{}'.format(rightColors[46]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st47"]')
block.set('style','fill:{}'.format(rightColors[47]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st48"]')
block.set('style','fill:{}'.format(rightColors[48]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st49"]')
block.set('style','fill:{}'.format(rightColors[49]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st50"]')
block.set('style','fill:{}'.format(rightColors[50]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st51"]')
block.set('style','fill:{}'.format(rightColors[51]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st52"]')
block.set('style','fill:{}'.format(rightColors[52]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st53"]')
block.set('style','fill:{}'.format(rightColors[53]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st54"]')
block.set('style','fill:{}'.format(rightColors[54]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st55"]')
block.set('style','fill:{}'.format(rightColors[55]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st56"]')
block.set('style','fill:{}'.format(rightColors[56]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st57"]')
block.set('style','fill:{}'.format(rightColors[57]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st58"]')
block.set('style','fill:{}'.format(rightColors[58]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st59"]')
block.set('style','fill:{}'.format(rightColors[59]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st60"]')
block.set('style','fill:{}'.format(rightColors[60]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st61"]')
block.set('style','fill:{}'.format(rightColors[61]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st62"]')
block.set('style','fill:{}'.format(rightColors[62]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st63"]')
block.set('style','fill:{}'.format(rightColors[63]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st64"]')
block.set('style','fill:{}'.format(rightColors[64]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st65"]')
block.set('style','fill:{}'.format(rightColors[65]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st66"]')
block.set('style','fill:{}'.format(rightColors[66]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st67"]')
block.set('style','fill:{}'.format(rightColors[67]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st68"]')
block.set('style','fill:{}'.format(rightColors[68]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st69"]')
block.set('style','fill:{}'.format(rightColors[69]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st70"]')
block.set('style','fill:{}'.format(rightColors[70]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st71"]')
block.set('style','fill:{}'.format(rightColors[71]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st72"]')
block.set('style','fill:{}'.format(rightColors[72]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st73"]')
block.set('style','fill:{}'.format(rightColors[73]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st74"]')
block.set('style','fill:{}'.format(rightColors[74]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st75"]')
block.set('style','fill:{}'.format(rightColors[75]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st76"]')
block.set('style','fill:{}'.format(rightColors[76]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st77"]')
block.set('style','fill:{}'.format(rightColors[77]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st78"]')
block.set('style','fill:{}'.format(rightColors[78]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st79"]')
block.set('style','fill:{}'.format(rightColors[79]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st80"]')
block.set('style','fill:{}'.format(rightColors[80]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st81"]')
block.set('style','fill:{}'.format(rightColors[81]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st82"]')
block.set('style','fill:{}'.format(rightColors[82]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st83"]')
block.set('style','fill:{}'.format(rightColors[83]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st84"]')
block.set('style','fill:{}'.format(rightColors[84]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st85"]')
block.set('style','fill:{}'.format(rightColors[85]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st86"]')
block.set('style','fill:{}'.format(rightColors[86]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st87"]')
block.set('style','fill:{}'.format(rightColors[87]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st88"]')
block.set('style','fill:{}'.format(rightColors[88]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st89"]')
block.set('style','fill:{}'.format(rightColors[89]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st90"]')
block.set('style','fill:{}'.format(rightColors[90]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st91"]')
block.set('style','fill:{}'.format(rightColors[91]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st92"]')
block.set('style','fill:{}'.format(rightColors[92]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st93"]')
block.set('style','fill:{}'.format(rightColors[93]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st94"]')
block.set('style','fill:{}'.format(rightColors[94]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st95"]')
block.set('style','fill:{}'.format(rightColors[95]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st96"]')
block.set('style','fill:{}'.format(rightColors[96]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st97"]')
block.set('style','fill:{}'.format(rightColors[97]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st98"]')
block.set('style','fill:{}'.format(rightColors[98]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st99"]')
block.set('style','fill:{}'.format(rightColors[99]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st100"]')
block.set('style','fill:{}'.format(rightColors[100]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st101"]')
block.set('style','fill:{}'.format(rightColors[101]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st102"]')
block.set('style','fill:{}'.format(rightColors[102]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st103"]')
block.set('style','fill:{}'.format(rightColors[103]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st104"]')
block.set('style','fill:{}'.format(rightColors[104]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st105"]')
block.set('style','fill:{}'.format(rightColors[105]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st106"]')
block.set('style','fill:{}'.format(rightColors[106]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st107"]')
block.set('style','fill:{}'.format(rightColors[107]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st108"]')
block.set('style','fill:{}'.format(rightColors[108]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st109"]')
block.set('style','fill:{}'.format(rightColors[109]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st110"]')
block.set('style','fill:{}'.format(rightColors[110]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st111"]')
block.set('style','fill:{}'.format(rightColors[111]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st112"]')
block.set('style','fill:{}'.format(rightColors[112]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st113"]')
block.set('style','fill:{}'.format(rightColors[113]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st114"]')
block.set('style','fill:{}'.format(rightColors[114]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st115"]')
block.set('style','fill:{}'.format(rightColors[115]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st116"]')
block.set('style','fill:{}'.format(rightColors[116]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st117"]')
block.set('style','fill:{}'.format(rightColors[117]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st118"]')
block.set('style','fill:{}'.format(rightColors[118]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st119"]')
block.set('style','fill:{}'.format(rightColors[119]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st120"]')
block.set('style','fill:{}'.format(rightColors[120]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st121"]')
block.set('style','fill:{}'.format(rightColors[121]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st122"]')
block.set('style','fill:{}'.format(rightColors[122]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st123"]')
block.set('style','fill:{}'.format(rightColors[123]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st124"]')
block.set('style','fill:{}'.format(rightColors[124]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st125"]')
block.set('style','fill:{}'.format(rightColors[125]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st126"]')
block.set('style','fill:{}'.format(rightColors[126]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st127"]')
block.set('style','fill:{}'.format(rightColors[127]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st128"]')
block.set('style','fill:{}'.format(rightColors[128]))
block=root.find('{http://www.w3.org/2000/svg}ellipse[@class="st129"]')
block.set('style','fill:{}'.format(rightColors[129]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st130"]')
block.set('style','fill:{}'.format(rightColors[130]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st131"]')
block.set('style','fill:{}'.format(rightColors[131]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st132"]')
block.set('style','fill:{}'.format(rightColors[132]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st133"]')
block.set('style','fill:{}'.format(rightColors[133]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st134"]')
block.set('style','fill:{}'.format(rightColors[134]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st135"]')
block.set('style','fill:{}'.format(rightColors[135]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st136"]')
block.set('style','fill:{}'.format(rightColors[136]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st137"]')
block.set('style','fill:{}'.format(rightColors[137]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st138"]')
block.set('style','fill:{}'.format(rightColors[138]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st139"]')
block.set('style','fill:{}'.format(rightColors[139]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st140"]')
block.set('style','fill:{}'.format(rightColors[140]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st141"]')
block.set('style','fill:{}'.format(rightColors[141]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st142"]')
block.set('style','fill:{}'.format(rightColors[142]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st143"]')
block.set('style','fill:{}'.format(rightColors[143]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st144"]')
block.set('style','fill:{}'.format(rightColors[144]))
block=root.find('{http://www.w3.org/2000/svg}ellipse[@class="st145"]')
block.set('style','fill:{}'.format(rightColors[145]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st146"]')
block.set('style','fill:{}'.format(rightColors[146]))
block=root.find('{http://www.w3.org/2000/svg}ellipse[@class="st147"]')
block.set('style','fill:{}'.format(rightColors[147]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st148"]')
block.set('style','fill:{}'.format(rightColors[148]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st149"]')
block.set('style','fill:{}'.format(rightColors[149]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st150"]')
block.set('style','fill:{}'.format(rightColors[150]))
block=root.find('{http://www.w3.org/2000/svg}ellipse[@class="st151"]')
block.set('style','fill:{}'.format(rightColors[151]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st152"]')
block.set('style','fill:{}'.format(rightColors[152]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st153"]')
block.set('style','fill:{}'.format(rightColors[153]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st154"]')
block.set('style','fill:{}'.format(rightColors[154]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st155"]')
block.set('style','fill:{}'.format(rightColors[155]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st156"]')
block.set('style','fill:{}'.format(rightColors[156]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st157"]')
block.set('style','fill:{}'.format(rightColors[157]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st158"]')
block.set('style','fill:{}'.format(rightColors[158]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st159"]')
block.set('style','fill:{}'.format(rightColors[159]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st160"]')
block.set('style','fill:{}'.format(rightColors[160]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st161"]')
block.set('style','fill:{}'.format(rightColors[161]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st162"]')
block.set('style','fill:{}'.format(rightColors[162]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st163"]')
block.set('style','fill:{}'.format(rightColors[163]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st164"]')
block.set('style','fill:{}'.format(rightColors[164]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st165"]')
block.set('style','fill:{}'.format(rightColors[165]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st166"]')
block.set('style','fill:{}'.format(rightColors[166]))
block=root.find('{http://www.w3.org/2000/svg}ellipse[@class="st167"]')
block.set('style','fill:{}'.format(rightColors[167]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st168"]')
block.set('style','fill:{}'.format(rightColors[168]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st169"]')
block.set('style','fill:{}'.format(rightColors[169]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st170"]')
block.set('style','fill:{}'.format(rightColors[170]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st171"]')
block.set('style','fill:{}'.format(rightColors[171]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st172"]')
block.set('style','fill:{}'.format(rightColors[172]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st173"]')
block.set('style','fill:{}'.format(rightColors[173]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st174"]')
block.set('style','fill:{}'.format(rightColors[174]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st175"]')
block.set('style','fill:{}'.format(rightColors[175]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st176"]')
block.set('style','fill:{}'.format(rightColors[176]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st177"]')
block.set('style','fill:{}'.format(rightColors[177]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st178"]')
block.set('style','fill:{}'.format(rightColors[178]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st179"]')
block.set('style','fill:{}'.format(rightColors[179]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st180"]')
block.set('style','fill:{}'.format(rightColors[180]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st181"]')
block.set('style','fill:{}'.format(rightColors[181]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st182"]')
block.set('style','fill:{}'.format(rightColors[182]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st183"]')
block.set('style','fill:{}'.format(rightColors[183]))
block=root.find('{http://www.w3.org/2000/svg}ellipse[@class="st184"]')
block.set('style','fill:{}'.format(rightColors[184]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st185"]')
block.set('style','fill:{}'.format(rightColors[185]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st186"]')
block.set('style','fill:{}'.format(rightColors[186]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st187"]')
block.set('style','fill:{}'.format(rightColors[187]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st188"]')
block.set('style','fill:{}'.format(rightColors[188]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st189"]')
block.set('style','fill:{}'.format(rightColors[189]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st190"]')
block.set('style','fill:{}'.format(rightColors[190]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st191"]')
block.set('style','fill:{}'.format(rightColors[191]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st192"]')
block.set('style','fill:{}'.format(rightColors[192]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st193"]')
block.set('style','fill:{}'.format(rightColors[193]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st194"]')
block.set('style','fill:{}'.format(rightColors[194]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st195"]')
block.set('style','fill:{}'.format(rightColors[195]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st196"]')
block.set('style','fill:{}'.format(rightColors[196]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st197"]')
block.set('style','fill:{}'.format(rightColors[197]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st198"]')
block.set('style','fill:{}'.format(rightColors[198]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st199"]')
block.set('style','fill:{}'.format(rightColors[199]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st200"]')
block.set('style','fill:{}'.format(rightColors[200]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st201"]')
block.set('style','fill:{}'.format(rightColors[201]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st202"]')
block.set('style','fill:{}'.format(rightColors[202]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st203"]')
block.set('style','fill:{}'.format(rightColors[203]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st204"]')
block.set('style','fill:{}'.format(rightColors[204]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st205"]')
block.set('style','fill:{}'.format(rightColors[205]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st206"]')
block.set('style','fill:{}'.format(rightColors[206]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st207"]')
block.set('style','fill:{}'.format(rightColors[207]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st208"]')
block.set('style','fill:{}'.format(rightColors[208]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st209"]')
block.set('style','fill:{}'.format(rightColors[209]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st210"]')
block.set('style','fill:{}'.format(rightColors[210]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st211"]')
block.set('style','fill:{}'.format(rightColors[210]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st212"]')
block.set('style','fill:{}'.format(rightColors[210]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st213"]')
block.set('style','fill:{}'.format(rightColors[210]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st214"]')
block.set('style','fill:{}'.format(rightColors[210]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st215"]')
block.set('style','fill:{}'.format(rightColors[211]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st216"]')
block.set('style','fill:{}'.format(rightColors[212]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st217"]')
block.set('style','fill:{}'.format(rightColors[213]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st218"]')
block.set('style','fill:{}'.format(rightColors[214]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st219"]')
block.set('style','fill:{}'.format(rightColors[215]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st220"]')
block.set('style','fill:{}'.format(rightColors[216]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st221"]')
block.set('style','fill:{}'.format(rightColors[217]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st222"]')
block.set('style','fill:{}'.format(rightColors[218]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st223"]')
block.set('style','fill:{}'.format(rightColors[219]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st224"]')
block.set('style','fill:{}'.format(rightColors[220]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st225"]')
block.set('style','fill:{}'.format(rightColors[221]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st226"]')
block.set('style','fill:{}'.format(rightColors[222]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st227"]')
block.set('style','fill:{}'.format(rightColors[223]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st228"]')
block.set('style','fill:{}'.format(rightColors[224]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st229"]')
block.set('style','fill:{}'.format(rightColors[225]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st230"]')
block.set('style','fill:{}'.format(rightColors[226]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st231"]')
block.set('style','fill:{}'.format(rightColors[227]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st232"]')
block.set('style','fill:{}'.format(rightColors[228]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st233"]')
block.set('style','fill:{}'.format(rightColors[229]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st234"]')
block.set('style','fill:{}'.format(rightColors[230]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st235"]')
block.set('style','fill:{}'.format(rightColors[231]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st236"]')
block.set('style','fill:{}'.format(rightColors[232]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st237"]')
block.set('style','fill:{}'.format(rightColors[233]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st238"]')
block.set('style','fill:{}'.format(rightColors[234]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st239"]')
block.set('style','fill:{}'.format(rightColors[235]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st240"]')
block.set('style','fill:{}'.format(rightColors[236]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st241"]')
block.set('style','fill:{}'.format(rightColors[237]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st242"]')
block.set('style','fill:{}'.format(rightColors[238]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st243"]')
block.set('style','fill:{}'.format(rightColors[239]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st244"]')
block.set('style','fill:{}'.format(rightColors[240]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st245"]')
block.set('style','fill:{}'.format(rightColors[241]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st246"]')
block.set('style','fill:{}'.format(rightColors[242]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st247"]')
block.set('style','fill:{}'.format(rightColors[243]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st248"]')
block.set('style','fill:{}'.format(rightColors[244]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st249"]')
block.set('style','fill:{}'.format(rightColors[245]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st250"]')
block.set('style','fill:{}'.format(rightColors[245]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st251"]')
block.set('style','fill:{}'.format(rightColors[246]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st252"]')
block.set('style','fill:{}'.format(rightColors[247]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st253"]')
block.set('style','fill:{}'.format(rightColors[248]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st254"]')
block.set('style','fill:{}'.format(rightColors[249]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st255"]')
block.set('style','fill:{}'.format(rightColors[250]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st256"]')
block.set('style','fill:{}'.format(rightColors[251]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st257"]')
block.set('style','fill:{}'.format(rightColors[252]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st258"]')
block.set('style','fill:{}'.format(rightColors[253]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st259"]')
block.set('style','fill:{}'.format(rightColors[254]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st260"]')
block.set('style','fill:{}'.format(rightColors[255]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st261"]')
block.set('style','fill:{}'.format(rightColors[256]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st262"]')
block.set('style','fill:{}'.format(rightColors[257]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st263"]')
block.set('style','fill:{}'.format(rightColors[258]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st264"]')
block.set('style','fill:{}'.format(rightColors[259]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st265"]')
block.set('style','fill:{}'.format(rightColors[260]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st266"]')
block.set('style','fill:{}'.format(rightColors[261]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st267"]')
block.set('style','fill:{}'.format(rightColors[262]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st268"]')
block.set('style','fill:{}'.format(rightColors[263]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st269"]')
block.set('style','fill:{}'.format(rightColors[264]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st270"]')
block.set('style','fill:{}'.format(rightColors[265]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st271"]')
block.set('style','fill:{}'.format(rightColors[266]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st272"]')
block.set('style','fill:{}'.format(rightColors[267]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st273"]')
block.set('style','fill:{}'.format(rightColors[268]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st274"]')
block.set('style','fill:{}'.format(rightColors[269]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st275"]')
block.set('style','fill:{}'.format(rightColors[270]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st276"]')
block.set('style','fill:{}'.format(rightColors[271]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st277"]')
block.set('style','fill:{}'.format(rightColors[272]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st278"]')
block.set('style','fill:{}'.format(rightColors[273]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st279"]')
block.set('style','fill:{}'.format(rightColors[274]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st280"]')
block.set('style','fill:{}'.format(rightColors[275]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st281"]')
block.set('style','fill:{}'.format(rightColors[276]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st282"]')
block.set('style','fill:{}'.format(rightColors[277]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st283"]')
block.set('style','fill:{}'.format(rightColors[278]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st284"]')
block.set('style','fill:{}'.format(rightColors[279]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st285"]')
block.set('style','fill:{}'.format(rightColors[280]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st286"]')
block.set('style','fill:{}'.format(rightColors[281]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st287"]')
block.set('style','fill:{}'.format(rightColors[282]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st288"]')
block.set('style','fill:{}'.format(rightColors[283]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st289"]')
block.set('style','fill:{}'.format(rightColors[284]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st290"]')
block.set('style','fill:{}'.format(rightColors[285]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st291"]')
block.set('style','fill:{}'.format(rightColors[286]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st292"]')
block.set('style','fill:{}'.format(rightColors[287]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st293"]')
block.set('style','fill:{}'.format(rightColors[288]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st294"]')
block.set('style','fill:{}'.format(rightColors[289]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st295"]')
block.set('style','fill:{}'.format(rightColors[290]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st296"]')
block.set('style','fill:{}'.format(rightColors[291]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st297"]')
block.set('style','fill:{}'.format(rightColors[292]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st298"]')
block.set('style','fill:{}'.format(rightColors[293]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st299"]')
block.set('style','fill:{}'.format(rightColors[294]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st300"]')
block.set('style','fill:{}'.format(rightColors[295]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st301"]')
block.set('style','fill:{}'.format(rightColors[296]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st302"]')
block.set('style','fill:{}'.format(rightColors[297]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st303"]')
block.set('style','fill:{}'.format(rightColors[298]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st304"]')
block.set('style','fill:{}'.format(rightColors[299]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st305"]')
block.set('style','fill:{}'.format(rightColors[300]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st306"]')
block.set('style','fill:{}'.format(rightColors[301]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st307"]')
block.set('style','fill:{}'.format(rightColors[302]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st308"]')
block.set('style','fill:{}'.format(rightColors[303]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st309"]')
block.set('style','fill:{}'.format(rightColors[304]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st310"]')
block.set('style','fill:{}'.format(rightColors[305]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st311"]')
block.set('style','fill:{}'.format(rightColors[306]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st312"]')
block.set('style','fill:{}'.format(rightColors[307]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st313"]')
block.set('style','fill:{}'.format(rightColors[308]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st314"]')
block.set('style','fill:{}'.format(rightColors[309]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st315"]')
block.set('style','fill:{}'.format(rightColors[310]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st316"]')
block.set('style','fill:{}'.format(rightColors[311]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st317"]')
block.set('style','fill:{}'.format(rightColors[312]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st318"]')
block.set('style','fill:{}'.format(rightColors[313]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st319"]')
block.set('style','fill:{}'.format(rightColors[314]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st320"]')
block.set('style','fill:{}'.format(rightColors[315]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st321"]')
block.set('style','fill:{}'.format(rightColors[316]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st322"]')
block.set('style','fill:{}'.format(rightColors[317]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st323"]')
block.set('style','fill:{}'.format(rightColors[318]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st324"]')
block.set('style','fill:{}'.format(rightColors[319]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st325"]')
block.set('style','fill:{}'.format(rightColors[320]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st326"]')
block.set('style','fill:{}'.format(rightColors[321]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st327"]')
block.set('style','fill:{}'.format(rightColors[322]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st328"]')
block.set('style','fill:{}'.format(rightColors[323]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st329"]')
block.set('style','fill:{}'.format(rightColors[324]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st330"]')
block.set('style','fill:{}'.format(rightColors[325]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st331"]')
block.set('style','fill:{}'.format(rightColors[326]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st332"]')
block.set('style','fill:{}'.format(rightColors[327]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st333"]')
block.set('style','fill:{}'.format(rightColors[328]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st334"]')
block.set('style','fill:{}'.format(rightColors[329]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st335"]')
block.set('style','fill:{}'.format(rightColors[330]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st336"]')
block.set('style','fill:{}'.format(rightColors[331]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st337"]')
block.set('style','fill:{}'.format(rightColors[332]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st338"]')
block.set('style','fill:{}'.format(rightColors[333]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st339"]')
block.set('style','fill:{}'.format(rightColors[334]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st340"]')
block.set('style','fill:{}'.format(rightColors[335]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st341"]')
block.set('style','fill:{}'.format(rightColors[336]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st342"]')
block.set('style','fill:{}'.format(rightColors[337]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st343"]')
block.set('style','fill:{}'.format(rightColors[338]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st344"]')
block.set('style','fill:{}'.format(rightColors[339]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st345"]')
block.set('style','fill:{}'.format(rightColors[340]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st346"]')
block.set('style','fill:{}'.format(rightColors[341]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st347"]')
block.set('style','fill:{}'.format(rightColors[342]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st348"]')
block.set('style','fill:{}'.format(rightColors[343]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st349"]')
block.set('style','fill:{}'.format(rightColors[344]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st350"]')
block.set('style','fill:{}'.format(rightColors[345]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st351"]')
block.set('style','fill:{}'.format(rightColors[346]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st352"]')
block.set('style','fill:{}'.format(rightColors[347]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st353"]')
block.set('style','fill:{}'.format(rightColors[348]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st354"]')
block.set('style','fill:{}'.format(rightColors[349]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st355"]')
block.set('style','fill:{}'.format(rightColors[350]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st356"]')
block.set('style','fill:{}'.format(rightColors[351]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st357"]')
block.set('style','fill:{}'.format(rightColors[352]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st358"]')
block.set('style','fill:{}'.format(rightColors[353]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st359"]')
block.set('style','fill:{}'.format(rightColors[354]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st360"]')
block.set('style','fill:{}'.format(rightColors[355]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st361"]')
block.set('style','fill:{}'.format(rightColors[356]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st362"]')
block.set('style','fill:{}'.format(rightColors[358]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st363"]')
block.set('style','fill:{}'.format(rightColors[357]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st364"]')
block.set('style','fill:{}'.format(rightColors[359]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st365"]')
block.set('style','fill:{}'.format(rightColors[360]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st366"]')
block.set('style','fill:{}'.format(rightColors[361]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st367"]')
block.set('style','fill:{}'.format(rightColors[362]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st368"]')
block.set('style','fill:{}'.format(rightColors[363]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st369"]')
block.set('style','fill:{}'.format(rightColors[364]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st370"]')
block.set('style','fill:{}'.format(rightColors[365]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st371"]')
block.set('style','fill:{}'.format(rightColors[366]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st372"]')
block.set('style','fill:{}'.format(rightColors[367]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st373"]')
block.set('style','fill:{}'.format(rightColors[368]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st374"]')
block.set('style','fill:{}'.format(rightColors[369]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st375"]')
block.set('style','fill:{}'.format(rightColors[370]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st376"]')
block.set('style','fill:{}'.format(rightColors[371]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st377"]')
block.set('style','fill:{}'.format(rightColors[372]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st378"]')
block.set('style','fill:{}'.format(rightColors[373]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st379"]')
block.set('style','fill:{}'.format(rightColors[374]))
block=root.find('{http://www.w3.org/2000/svg}ellipse[@class="st380"]')
block.set('style','fill:{}'.format(rightColors[375]))
block=root.find('{http://www.w3.org/2000/svg}ellipse[@class="st381"]')
block.set('style','fill:{}'.format(rightColors[376]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st382"]')
block.set('style','fill:{}'.format(rightColors[377]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st383"]')
block.set('style','fill:{}'.format(rightColors[378]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st384"]')
block.set('style','fill:{}'.format(rightColors[379]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st385"]')
block.set('style','fill:{}'.format(rightColors[380]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st386"]')
block.set('style','fill:{}'.format(rightColors[381]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st387"]')
block.set('style','fill:{}'.format(leftColors[0]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st388"]')
block.set('style','fill:{}'.format(leftColors[1]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st389"]')
block.set('style','fill:{}'.format(leftColors[2]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st390"]')
block.set('style','fill:{}'.format(leftColors[3]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st391"]')
block.set('style','fill:{}'.format(leftColors[4]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st392"]')
block.set('style','fill:{}'.format(leftColors[5]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st393"]')
block.set('style','fill:{}'.format(leftColors[6]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st394"]')
block.set('style','fill:{}'.format(leftColors[7]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st395"]')
block.set('style','fill:{}'.format(leftColors[8]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st396"]')
block.set('style','fill:{}'.format(leftColors[9]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st397"]')
block.set('style','fill:{}'.format(leftColors[10]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st398"]')
block.set('style','fill:{}'.format(leftColors[11]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st399"]')
block.set('style','fill:{}'.format(leftColors[12]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st400"]')
block.set('style','fill:{}'.format(leftColors[13]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st401"]')
block.set('style','fill:{}'.format(leftColors[14]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st402"]')
block.set('style','fill:{}'.format(leftColors[15]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st403"]')
block.set('style','fill:{}'.format(leftColors[16]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st404"]')
block.set('style','fill:{}'.format(leftColors[17]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st405"]')
block.set('style','fill:{}'.format(leftColors[18]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st406"]')
block.set('style','fill:{}'.format(leftColors[19]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st407"]')
block.set('style','fill:{}'.format(leftColors[20]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st408"]')
block.set('style','fill:{}'.format(leftColors[21]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st409"]')
block.set('style','fill:{}'.format(leftColors[22]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st410"]')
block.set('style','fill:{}'.format(leftColors[23]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st411"]')
block.set('style','fill:{}'.format(leftColors[24]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st412"]')
block.set('style','fill:{}'.format(leftColors[25]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st413"]')
block.set('style','fill:{}'.format(leftColors[26]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st414"]')
block.set('style','fill:{}'.format(leftColors[27]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st415"]')
block.set('style','fill:{}'.format(leftColors[28]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st416"]')
block.set('style','fill:{}'.format(leftColors[29]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st417"]')
block.set('style','fill:{}'.format(leftColors[30]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st418"]')
block.set('style','fill:{}'.format(leftColors[31]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st419"]')
block.set('style','fill:{}'.format(leftColors[32]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st420"]')
block.set('style','fill:{}'.format(leftColors[33]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st421"]')
block.set('style','fill:{}'.format(leftColors[34]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st422"]')
block.set('style','fill:{}'.format(leftColors[35]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st423"]')
block.set('style','fill:{}'.format(leftColors[36]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st424"]')
block.set('style','fill:{}'.format(leftColors[37]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st425"]')
block.set('style','fill:{}'.format(leftColors[38]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st426"]')
block.set('style','fill:{}'.format(leftColors[39]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st427"]')
block.set('style','fill:{}'.format(leftColors[40]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st428"]')
block.set('style','fill:{}'.format(leftColors[41]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st429"]')
block.set('style','fill:{}'.format(leftColors[42]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st430"]')
block.set('style','fill:{}'.format(leftColors[43]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st431"]')
block.set('style','fill:{}'.format(leftColors[44]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st432"]')
block.set('style','fill:{}'.format(leftColors[45]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st433"]')
block.set('style','fill:{}'.format(leftColors[46]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st434"]')
block.set('style','fill:{}'.format(leftColors[47]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st435"]')
block.set('style','fill:{}'.format(leftColors[48]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st436"]')
block.set('style','fill:{}'.format(leftColors[49]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st437"]')
block.set('style','fill:{}'.format(leftColors[50]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st438"]')
block.set('style','fill:{}'.format(leftColors[51]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st439"]')
block.set('style','fill:{}'.format(leftColors[52]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st440"]')
block.set('style','fill:{}'.format(leftColors[53]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st441"]')
block.set('style','fill:{}'.format(leftColors[54]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st442"]')
block.set('style','fill:{}'.format(leftColors[55]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st443"]')
block.set('style','fill:{}'.format(leftColors[56]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st444"]')
block.set('style','fill:{}'.format(leftColors[57]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st445"]')
block.set('style','fill:{}'.format(leftColors[58]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st446"]')
block.set('style','fill:{}'.format(leftColors[59]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st447"]')
block.set('style','fill:{}'.format(leftColors[60]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st448"]')
block.set('style','fill:{}'.format(leftColors[61]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st449"]')
block.set('style','fill:{}'.format(leftColors[62]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st450"]')
block.set('style','fill:{}'.format(leftColors[63]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st451"]')
block.set('style','fill:{}'.format(leftColors[64]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st452"]')
block.set('style','fill:{}'.format(leftColors[65]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st453"]')
block.set('style','fill:{}'.format(leftColors[66]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st454"]')
block.set('style','fill:{}'.format(leftColors[67]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st455"]')
block.set('style','fill:{}'.format(leftColors[68]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st456"]')
block.set('style','fill:{}'.format(leftColors[69]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st457"]')
block.set('style','fill:{}'.format(leftColors[70]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st458"]')
block.set('style','fill:{}'.format(leftColors[71]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st459"]')
block.set('style','fill:{}'.format(leftColors[72]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st460"]')
block.set('style','fill:{}'.format(leftColors[73]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st461"]')
block.set('style','fill:{}'.format(leftColors[74]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st462"]')
block.set('style','fill:{}'.format(leftColors[75]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st463"]')
block.set('style','fill:{}'.format(leftColors[76]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st464"]')
block.set('style','fill:{}'.format(leftColors[77]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st465"]')
block.set('style','fill:{}'.format(leftColors[78]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st466"]')
block.set('style','fill:{}'.format(leftColors[79]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st467"]')
block.set('style','fill:{}'.format(leftColors[80]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st468"]')
block.set('style','fill:{}'.format(leftColors[81]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st469"]')
block.set('style','fill:{}'.format(leftColors[82]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st470"]')
block.set('style','fill:{}'.format(leftColors[83]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st471"]')
block.set('style','fill:{}'.format(leftColors[84]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st472"]')
block.set('style','fill:{}'.format(leftColors[85]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st473"]')
block.set('style','fill:{}'.format(leftColors[86]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st474"]')
block.set('style','fill:{}'.format(leftColors[87]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st475"]')
block.set('style','fill:{}'.format(leftColors[88]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st476"]')
block.set('style','fill:{}'.format(leftColors[89]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st477"]')
block.set('style','fill:{}'.format(leftColors[90]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st478"]')
block.set('style','fill:{}'.format(leftColors[91]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st479"]')
block.set('style','fill:{}'.format(leftColors[92]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st480"]')
block.set('style','fill:{}'.format(leftColors[93]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st481"]')
block.set('style','fill:{}'.format(leftColors[94]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st482"]')
block.set('style','fill:{}'.format(leftColors[95]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st483"]')
block.set('style','fill:{}'.format(leftColors[96]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st484"]')
block.set('style','fill:{}'.format(leftColors[97]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st485"]')
block.set('style','fill:{}'.format(leftColors[98]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st486"]')
block.set('style','fill:{}'.format(leftColors[99]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st487"]')
block.set('style','fill:{}'.format(leftColors[100]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st488"]')
block.set('style','fill:{}'.format(leftColors[101]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st489"]')
block.set('style','fill:{}'.format(leftColors[102]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st490"]')
block.set('style','fill:{}'.format(leftColors[103]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st491"]')
block.set('style','fill:{}'.format(leftColors[104]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st492"]')
block.set('style','fill:{}'.format(leftColors[105]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st493"]')
block.set('style','fill:{}'.format(leftColors[106]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st494"]')
block.set('style','fill:{}'.format(leftColors[107]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st495"]')
block.set('style','fill:{}'.format(leftColors[108]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st496"]')
block.set('style','fill:{}'.format(leftColors[109]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st497"]')
block.set('style','fill:{}'.format(leftColors[110]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st498"]')
block.set('style','fill:{}'.format(leftColors[111]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st499"]')
block.set('style','fill:{}'.format(leftColors[112]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st500"]')
block.set('style','fill:{}'.format(leftColors[113]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st501"]')
block.set('style','fill:{}'.format(leftColors[114]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st502"]')
block.set('style','fill:{}'.format(leftColors[115]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st503"]')
block.set('style','fill:{}'.format(leftColors[116]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st504"]')
block.set('style','fill:{}'.format(leftColors[117]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st505"]')
block.set('style','fill:{}'.format(leftColors[118]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st506"]')
block.set('style','fill:{}'.format(leftColors[119]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st507"]')
block.set('style','fill:{}'.format(leftColors[120]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st508"]')
block.set('style','fill:{}'.format(leftColors[121]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st509"]')
block.set('style','fill:{}'.format(leftColors[122]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st510"]')
block.set('style','fill:{}'.format(leftColors[123]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st511"]')
block.set('style','fill:{}'.format(leftColors[124]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st512"]')
block.set('style','fill:{}'.format(leftColors[125]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st513"]')
block.set('style','fill:{}'.format(leftColors[126]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st514"]')
block.set('style','fill:{}'.format(leftColors[127]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st515"]')
block.set('style','fill:{}'.format(leftColors[128]))
block=root.find('{http://www.w3.org/2000/svg}ellipse[@class="st516"]')
block.set('style','fill:{}'.format(leftColors[129]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st517"]')
block.set('style','fill:{}'.format(leftColors[130]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st518"]')
block.set('style','fill:{}'.format(leftColors[131]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st519"]')
block.set('style','fill:{}'.format(leftColors[132]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st520"]')
block.set('style','fill:{}'.format(leftColors[133]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st521"]')
block.set('style','fill:{}'.format(leftColors[134]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st522"]')
block.set('style','fill:{}'.format(leftColors[135]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st523"]')
block.set('style','fill:{}'.format(leftColors[136]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st524"]')
block.set('style','fill:{}'.format(leftColors[137]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st525"]')
block.set('style','fill:{}'.format(leftColors[138]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st526"]')
block.set('style','fill:{}'.format(leftColors[139]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st527"]')
block.set('style','fill:{}'.format(leftColors[140]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st528"]')
block.set('style','fill:{}'.format(leftColors[141]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st529"]')
block.set('style','fill:{}'.format(leftColors[142]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st530"]')
block.set('style','fill:{}'.format(leftColors[143]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st531"]')
block.set('style','fill:{}'.format(leftColors[144]))
block=root.find('{http://www.w3.org/2000/svg}ellipse[@class="st532"]')
block.set('style','fill:{}'.format(leftColors[145]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st533"]')
block.set('style','fill:{}'.format(leftColors[146]))
block=root.find('{http://www.w3.org/2000/svg}ellipse[@class="st534"]')
block.set('style','fill:{}'.format(leftColors[147]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st535"]')
block.set('style','fill:{}'.format(leftColors[148]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st536"]')
block.set('style','fill:{}'.format(leftColors[149]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st537"]')
block.set('style','fill:{}'.format(leftColors[150]))
block=root.find('{http://www.w3.org/2000/svg}ellipse[@class="st538"]')
block.set('style','fill:{}'.format(leftColors[151]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st539"]')
block.set('style','fill:{}'.format(leftColors[152]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st540"]')
block.set('style','fill:{}'.format(leftColors[153]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st541"]')
block.set('style','fill:{}'.format(leftColors[154]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st542"]')
block.set('style','fill:{}'.format(leftColors[155]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st543"]')
block.set('style','fill:{}'.format(leftColors[156]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st544"]')
block.set('style','fill:{}'.format(leftColors[157]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st545"]')
block.set('style','fill:{}'.format(leftColors[158]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st546"]')
block.set('style','fill:{}'.format(leftColors[159]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st547"]')
block.set('style','fill:{}'.format(leftColors[160]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st548"]')
block.set('style','fill:{}'.format(leftColors[161]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st549"]')
block.set('style','fill:{}'.format(leftColors[162]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st550"]')
block.set('style','fill:{}'.format(leftColors[163]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st551"]')
block.set('style','fill:{}'.format(leftColors[164]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st552"]')
block.set('style','fill:{}'.format(leftColors[165]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st553"]')
block.set('style','fill:{}'.format(leftColors[166]))
block=root.find('{http://www.w3.org/2000/svg}ellipse[@class="st554"]')
block.set('style','fill:{}'.format(leftColors[167]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st555"]')
block.set('style','fill:{}'.format(leftColors[168]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st556"]')
block.set('style','fill:{}'.format(leftColors[169]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st557"]')
block.set('style','fill:{}'.format(leftColors[170]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st558"]')
block.set('style','fill:{}'.format(leftColors[171]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st559"]')
block.set('style','fill:{}'.format(leftColors[172]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st560"]')
block.set('style','fill:{}'.format(leftColors[173]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st561"]')
block.set('style','fill:{}'.format(leftColors[174]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st562"]')
block.set('style','fill:{}'.format(leftColors[175]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st563"]')
block.set('style','fill:{}'.format(leftColors[176]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st564"]')
block.set('style','fill:{}'.format(leftColors[177]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st565"]')
block.set('style','fill:{}'.format(leftColors[178]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st566"]')
block.set('style','fill:{}'.format(leftColors[179]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st567"]')
block.set('style','fill:{}'.format(leftColors[180]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st568"]')
block.set('style','fill:{}'.format(leftColors[181]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st569"]')
block.set('style','fill:{}'.format(leftColors[182]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st570"]')
block.set('style','fill:{}'.format(leftColors[183]))
block=root.find('{http://www.w3.org/2000/svg}ellipse[@class="st571"]')
block.set('style','fill:{}'.format(leftColors[184]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st572"]')
block.set('style','fill:{}'.format(leftColors[185]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st573"]')
block.set('style','fill:{}'.format(leftColors[186]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st574"]')
block.set('style','fill:{}'.format(leftColors[187]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st575"]')
block.set('style','fill:{}'.format(leftColors[188]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st576"]')
block.set('style','fill:{}'.format(leftColors[189]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st577"]')
block.set('style','fill:{}'.format(leftColors[190]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st578"]')
block.set('style','fill:{}'.format(leftColors[191]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st579"]')
block.set('style','fill:{}'.format(leftColors[192]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st580"]')
block.set('style','fill:{}'.format(leftColors[193]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st581"]')
block.set('style','fill:{}'.format(leftColors[194]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st582"]')
block.set('style','fill:{}'.format(leftColors[195]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st583"]')
block.set('style','fill:{}'.format(leftColors[196]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st584"]')
block.set('style','fill:{}'.format(leftColors[197]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st585"]')
block.set('style','fill:{}'.format(leftColors[198]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st586"]')
block.set('style','fill:{}'.format(leftColors[199]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st587"]')
block.set('style','fill:{}'.format(leftColors[200]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st588"]')
block.set('style','fill:{}'.format(leftColors[201]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st589"]')
block.set('style','fill:{}'.format(leftColors[202]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st590"]')
block.set('style','fill:{}'.format(leftColors[203]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st591"]')
block.set('style','fill:{}'.format(leftColors[204]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st592"]')
block.set('style','fill:{}'.format(leftColors[205]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st593"]')
block.set('style','fill:{}'.format(leftColors[206]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st594"]')
block.set('style','fill:{}'.format(leftColors[207]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st595"]')
block.set('style','fill:{}'.format(leftColors[208]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st596"]')
block.set('style','fill:{}'.format(leftColors[209]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st597"]')
block.set('style','fill:{}'.format(leftColors[210]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st598"]')
block.set('style','fill:{}'.format(leftColors[210]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st599"]')
block.set('style','fill:{}'.format(leftColors[210]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st600"]')
block.set('style','fill:{}'.format(leftColors[210]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st601"]')
block.set('style','fill:{}'.format(leftColors[210]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st602"]')
block.set('style','fill:{}'.format(leftColors[211]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st603"]')
block.set('style','fill:{}'.format(leftColors[212]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st604"]')
block.set('style','fill:{}'.format(leftColors[213]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st605"]')
block.set('style','fill:{}'.format(leftColors[214]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st606"]')
block.set('style','fill:{}'.format(leftColors[215]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st607"]')
block.set('style','fill:{}'.format(leftColors[216]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st608"]')
block.set('style','fill:{}'.format(leftColors[217]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st609"]')
block.set('style','fill:{}'.format(leftColors[218]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st610"]')
block.set('style','fill:{}'.format(leftColors[219]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st611"]')
block.set('style','fill:{}'.format(leftColors[220]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st612"]')
block.set('style','fill:{}'.format(leftColors[221]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st613"]')
block.set('style','fill:{}'.format(leftColors[222]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st614"]')
block.set('style','fill:{}'.format(leftColors[223]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st615"]')
block.set('style','fill:{}'.format(leftColors[224]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st616"]')
block.set('style','fill:{}'.format(leftColors[225]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st617"]')
block.set('style','fill:{}'.format(leftColors[226]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st618"]')
block.set('style','fill:{}'.format(leftColors[227]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st619"]')
block.set('style','fill:{}'.format(leftColors[228]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st620"]')
block.set('style','fill:{}'.format(leftColors[229]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st621"]')
block.set('style','fill:{}'.format(leftColors[230]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st622"]')
block.set('style','fill:{}'.format(leftColors[231]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st623"]')
block.set('style','fill:{}'.format(leftColors[232]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st624"]')
block.set('style','fill:{}'.format(leftColors[233]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st625"]')
block.set('style','fill:{}'.format(leftColors[234]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st626"]')
block.set('style','fill:{}'.format(leftColors[235]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st627"]')
block.set('style','fill:{}'.format(leftColors[236]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st628"]')
block.set('style','fill:{}'.format(leftColors[237]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st629"]')
block.set('style','fill:{}'.format(leftColors[238]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st630"]')
block.set('style','fill:{}'.format(leftColors[239]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st631"]')
block.set('style','fill:{}'.format(leftColors[240]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st632"]')
block.set('style','fill:{}'.format(leftColors[241]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st633"]')
block.set('style','fill:{}'.format(leftColors[242]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st634"]')
block.set('style','fill:{}'.format(leftColors[243]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st635"]')
block.set('style','fill:{}'.format(leftColors[244]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st636"]')
block.set('style','fill:{}'.format(leftColors[245]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st637"]')
block.set('style','fill:{}'.format(leftColors[245]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st638"]')
block.set('style','fill:{}'.format(leftColors[246]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st639"]')
block.set('style','fill:{}'.format(leftColors[247]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st640"]')
block.set('style','fill:{}'.format(leftColors[248]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st641"]')
block.set('style','fill:{}'.format(leftColors[249]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st642"]')
block.set('style','fill:{}'.format(leftColors[250]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st643"]')
block.set('style','fill:{}'.format(leftColors[251]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st644"]')
block.set('style','fill:{}'.format(leftColors[252]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st645"]')
block.set('style','fill:{}'.format(leftColors[253]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st646"]')
block.set('style','fill:{}'.format(leftColors[254]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st647"]')
block.set('style','fill:{}'.format(leftColors[255]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st648"]')
block.set('style','fill:{}'.format(leftColors[256]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st649"]')
block.set('style','fill:{}'.format(leftColors[257]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st650"]')
block.set('style','fill:{}'.format(leftColors[258]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st651"]')
block.set('style','fill:{}'.format(leftColors[259]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st652"]')
block.set('style','fill:{}'.format(leftColors[260]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st653"]')
block.set('style','fill:{}'.format(leftColors[261]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st654"]')
block.set('style','fill:{}'.format(leftColors[262]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st655"]')
block.set('style','fill:{}'.format(leftColors[263]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st656"]')
block.set('style','fill:{}'.format(leftColors[264]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st657"]')
block.set('style','fill:{}'.format(leftColors[265]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st658"]')
block.set('style','fill:{}'.format(leftColors[266]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st659"]')
block.set('style','fill:{}'.format(leftColors[267]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st660"]')
block.set('style','fill:{}'.format(leftColors[268]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st661"]')
block.set('style','fill:{}'.format(leftColors[269]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st662"]')
block.set('style','fill:{}'.format(leftColors[270]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st663"]')
block.set('style','fill:{}'.format(leftColors[271]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st664"]')
block.set('style','fill:{}'.format(leftColors[272]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st665"]')
block.set('style','fill:{}'.format(leftColors[273]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st666"]')
block.set('style','fill:{}'.format(leftColors[274]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st667"]')
block.set('style','fill:{}'.format(leftColors[275]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st668"]')
block.set('style','fill:{}'.format(leftColors[276]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st669"]')
block.set('style','fill:{}'.format(leftColors[277]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st670"]')
block.set('style','fill:{}'.format(leftColors[278]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st671"]')
block.set('style','fill:{}'.format(leftColors[279]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st672"]')
block.set('style','fill:{}'.format(leftColors[280]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st673"]')
block.set('style','fill:{}'.format(leftColors[281]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st674"]')
block.set('style','fill:{}'.format(leftColors[282]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st675"]')
block.set('style','fill:{}'.format(leftColors[283]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st676"]')
block.set('style','fill:{}'.format(leftColors[284]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st677"]')
block.set('style','fill:{}'.format(leftColors[285]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st678"]')
block.set('style','fill:{}'.format(leftColors[286]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st679"]')
block.set('style','fill:{}'.format(leftColors[287]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st680"]')
block.set('style','fill:{}'.format(leftColors[288]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st681"]')
block.set('style','fill:{}'.format(leftColors[289]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st682"]')
block.set('style','fill:{}'.format(leftColors[290]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st683"]')
block.set('style','fill:{}'.format(leftColors[291]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st684"]')
block.set('style','fill:{}'.format(leftColors[292]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st685"]')
block.set('style','fill:{}'.format(leftColors[293]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st686"]')
block.set('style','fill:{}'.format(leftColors[294]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st687"]')
block.set('style','fill:{}'.format(leftColors[295]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st688"]')
block.set('style','fill:{}'.format(leftColors[296]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st689"]')
block.set('style','fill:{}'.format(leftColors[297]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st690"]')
block.set('style','fill:{}'.format(leftColors[298]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st691"]')
block.set('style','fill:{}'.format(leftColors[299]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st692"]')
block.set('style','fill:{}'.format(leftColors[300]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st693"]')
block.set('style','fill:{}'.format(leftColors[301]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st694"]')
block.set('style','fill:{}'.format(leftColors[302]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st695"]')
block.set('style','fill:{}'.format(leftColors[303]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st696"]')
block.set('style','fill:{}'.format(leftColors[304]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st697"]')
block.set('style','fill:{}'.format(leftColors[305]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st698"]')
block.set('style','fill:{}'.format(leftColors[306]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st699"]')
block.set('style','fill:{}'.format(leftColors[307]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st700"]')
block.set('style','fill:{}'.format(leftColors[308]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st701"]')
block.set('style','fill:{}'.format(leftColors[309]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st702"]')
block.set('style','fill:{}'.format(leftColors[310]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st703"]')
block.set('style','fill:{}'.format(leftColors[311]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st704"]')
block.set('style','fill:{}'.format(leftColors[312]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st705"]')
block.set('style','fill:{}'.format(leftColors[313]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st706"]')
block.set('style','fill:{}'.format(leftColors[314]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st707"]')
block.set('style','fill:{}'.format(leftColors[315]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st708"]')
block.set('style','fill:{}'.format(leftColors[316]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st709"]')
block.set('style','fill:{}'.format(leftColors[317]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st710"]')
block.set('style','fill:{}'.format(leftColors[318]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st711"]')
block.set('style','fill:{}'.format(leftColors[319]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st712"]')
block.set('style','fill:{}'.format(leftColors[320]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st713"]')
block.set('style','fill:{}'.format(leftColors[321]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st714"]')
block.set('style','fill:{}'.format(leftColors[322]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st715"]')
block.set('style','fill:{}'.format(leftColors[323]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st716"]')
block.set('style','fill:{}'.format(leftColors[324]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st717"]')
block.set('style','fill:{}'.format(leftColors[325]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st718"]')
block.set('style','fill:{}'.format(leftColors[326]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st719"]')
block.set('style','fill:{}'.format(leftColors[327]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st720"]')
block.set('style','fill:{}'.format(leftColors[328]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st721"]')
block.set('style','fill:{}'.format(leftColors[329]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st722"]')
block.set('style','fill:{}'.format(leftColors[330]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st723"]')
block.set('style','fill:{}'.format(leftColors[331]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st724"]')
block.set('style','fill:{}'.format(leftColors[332]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st725"]')
block.set('style','fill:{}'.format(leftColors[333]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st726"]')
block.set('style','fill:{}'.format(leftColors[334]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st727"]')
block.set('style','fill:{}'.format(leftColors[335]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st728"]')
block.set('style','fill:{}'.format(leftColors[336]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st729"]')
block.set('style','fill:{}'.format(leftColors[337]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st730"]')
block.set('style','fill:{}'.format(leftColors[338]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st731"]')
block.set('style','fill:{}'.format(leftColors[339]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st732"]')
block.set('style','fill:{}'.format(leftColors[340]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st733"]')
block.set('style','fill:{}'.format(leftColors[341]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st734"]')
block.set('style','fill:{}'.format(leftColors[342]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st735"]')
block.set('style','fill:{}'.format(leftColors[343]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st736"]')
block.set('style','fill:{}'.format(leftColors[344]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st737"]')
block.set('style','fill:{}'.format(leftColors[345]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st738"]')
block.set('style','fill:{}'.format(leftColors[346]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st739"]')
block.set('style','fill:{}'.format(leftColors[347]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st740"]')
block.set('style','fill:{}'.format(leftColors[348]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st741"]')
block.set('style','fill:{}'.format(leftColors[349]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st742"]')
block.set('style','fill:{}'.format(leftColors[350]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st743"]')
block.set('style','fill:{}'.format(leftColors[351]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st744"]')
block.set('style','fill:{}'.format(leftColors[352]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st745"]')
block.set('style','fill:{}'.format(leftColors[353]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st746"]')
block.set('style','fill:{}'.format(leftColors[354]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st747"]')
block.set('style','fill:{}'.format(leftColors[355]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st748"]')
block.set('style','fill:{}'.format(leftColors[356]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st749"]')
block.set('style','fill:{}'.format(leftColors[358]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st750"]')
block.set('style','fill:{}'.format(leftColors[357]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st751"]')
block.set('style','fill:{}'.format(leftColors[359]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st752"]')
block.set('style','fill:{}'.format(leftColors[360]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st753"]')
block.set('style','fill:{}'.format(leftColors[361]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st754"]')
block.set('style','fill:{}'.format(leftColors[362]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st755"]')
block.set('style','fill:{}'.format(leftColors[363]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st756"]')
block.set('style','fill:{}'.format(leftColors[364]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st757"]')
block.set('style','fill:{}'.format(leftColors[365]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st758"]')
block.set('style','fill:{}'.format(leftColors[366]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st759"]')
block.set('style','fill:{}'.format(leftColors[367]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st760"]')
block.set('style','fill:{}'.format(leftColors[368]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st761"]')
block.set('style','fill:{}'.format(leftColors[369]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st762"]')
block.set('style','fill:{}'.format(leftColors[370]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st763"]')
block.set('style','fill:{}'.format(leftColors[371]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st764"]')
block.set('style','fill:{}'.format(leftColors[372]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st765"]')
block.set('style','fill:{}'.format(leftColors[373]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st766"]')
block.set('style','fill:{}'.format(leftColors[374]))
block=root.find('{http://www.w3.org/2000/svg}ellipse[@class="st767"]')
block.set('style','fill:{}'.format(leftColors[375]))
block=root.find('{http://www.w3.org/2000/svg}ellipse[@class="st768"]')
block.set('style','fill:{}'.format(leftColors[376]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st769"]')
block.set('style','fill:{}'.format(leftColors[377]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st770"]')
block.set('style','fill:{}'.format(leftColors[378]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st771"]')
block.set('style','fill:{}'.format(leftColors[379]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st772"]')
block.set('style','fill:{}'.format(leftColors[380]))
block=root.find('{http://www.w3.org/2000/svg}path[@class="st773"]')
block.set('style','fill:{}'.format(leftColors[381]))
# find the class associated with each brain region and assign it the new color

tree.write('mouseFlatmap.svg')
svg=svg2rlg("mouseFlatmap.svg")
renderPDF.drawToFile(svg,"mouseFlatmap.pdf")
# write the new region colors to the SVG file and export as an SVG and PDF without border lines or the key

flatmap=open('mouseFlatmap.pdf','rb')
mapReader=PyPDF2.PdfReader(flatmap)
firstPage=mapReader.pages[0]
overlayReader=PyPDF2.PdfReader(open('mouseOverlay.pdf','rb'))
firstPage.merge_page(overlayReader.pages[0])
mapWriter=PyPDF2.PdfWriter()
mapWriter.add_page(firstPage)
for page in range(1,len(mapReader.pages)):
     pageObj=mapReader.pages[page]
     mapWriter.add_page(pageObj)
mapWithOverlay=open('mouseFlatmapWithKey.pdf','wb')
mapWriter.write(mapWithOverlay)
flatmap.close()
mapWithOverlay.close()
# overlays the flatmap border lines and color key onto the new flatmap
