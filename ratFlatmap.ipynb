# %% [markdown]
# 1. Play this cell the first time you open this file only.

# %%
pip install numpy
pip install torch torchvision

# %% [markdown]
# 2. Play this cell and follow the instructions in the output to give Google permission to change the flatmap file's colors with this code.
#
# ---

# %%
from google.colab import drive
drive.mount('/content/drive')
# !ls
# %cd drive/Shared \drives/Research/Rat/
# %cd drive/Rat/
# !ls
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# drive  sample_data
# [Errno 2] No such file or directory: 'drive/Rat/'
# /content
# drive  sample_data

# %% [markdown]
# 3. Play this cell and when it's done loading, you can view your updated flatmap as "ex.svg" in the folder.

# %%
import defusedxml.ElementTree as ET
import pandas
import numpy
import torch

# Part 1: Data Input
inputtedData=pandas.read_excel('ratInputtedData.xlsx')
# inputs data chosen to represent activation in heat map
data=inputtedData['Values']
minimum=min(data)
# finds minimum of inputtedData's second column
data.sort_values()
# sorts Values in numerical order
if minimum==0:
  minimum=data[1]
# if minimum is 0, sets minimum to second smallest number
maximum=max(data)
# finds maximum of inputtedData's second column
r=numpy.linspace(minimum,maximum,num=8)
# creates row vector of eight range values evenly spaced between minimum and maximum of inputtedData, to create 7 buckets
colors=['#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999','#999999']
# creates a matrix of grey colors with an index for each brain region represented

# Part 2: Color Allocation
color0='#000000'
# creates zero RGB value
color1='#FFE1E1'
# creates very weak RGB value
color2='#FFC0C0'
# creates weak RGB value
color3='#FF9191'
# creates weak-moderate RGB value
color4='#FF0000'
# creates moderate RGB value
color5='#C80200'
# creates moderate-strong RGB value
color6='#960200'
# creates strong RGB value
color7='#710200'
# creates very strong RGB value

for indexData in range(0,835):
    if data[indexData]==0:
        colors[indexData]=color0
        # assigns color0 to inputtedData values equal to 0
    elif data[indexData]<=r[1]:
        colors[indexData]=color1
        # assigns color1 to inputtedData values less than or equal to the second value of range
    elif data[indexData]<=r[2]:
        colors[indexData]=color2
        # assigns color2 to inputtedData values less than or equal to the third value of range
    elif data[indexData]<=r[3]:
        colors[indexData]=color3
        # assigns color3 to inputtedData values less than or equal to the fourth value of range
    elif data[indexData]<=r[4]:
        colors[indexData]=color4
        # assigns color4 to inputtedData values less than or equal to the fifth value of range
    elif data[indexData]<=r[5]:
        colors[indexData]=color5 
        # assigns color5 to inputtedData values less than or equal to the sixth value of range
    elif data[indexData]<=r[6]:
        colors[indexData]=color6
        # assigns color6 to inputtedData values less than or equal to the seventh value of range
    elif data[indexData]<=r[7]:
        colors[indexData]=color7
        # assigns color7 to inputtedData values less than or equal to the eighth value of range

# Load SVG as xml file
tree = ET.parse("RtBF5regions.svg")

# Get tree's root (all appended to it)
root = tree.getroot()

block = root.find('{http://www.w3.org/2000/svg}path[@class="_6b_Left"]')
block.set('style','fill:{}'.format(colors[0]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="_6b_Right"]')
block.set('style','fill:{}'.format(colors[1]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="AAA_Left"]')
block.set('style','fill:{}'.format(colors[2]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="AAA_Right"]')
block.set('style','fill:{}'.format(colors[3]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="ACAd_Left"]')
block.set('style','fill:{}'.format(colors[4]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="ACAd_Right"]')
block.set('style','fill:{}'.format(colors[5]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="ACAv_Left"]')
block.set('style','fill:{}'.format(colors[6]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="ACAv_Right"]')
block.set('style','fill:{}'.format(colors[7]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="ACB_Left"]')
block.set('style','fill:{}'.format(colors[8]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="ACB_Right"]')
block.set('style','fill:{}'.format(colors[9]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="ACU_Left"]')
block.set('style','fill:{}'.format(colors[10]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="ACU_Right"]')
block.set('style','fill:{}'.format(colors[11]))
block = root.find('{http://www.w3.org/2000/svg}ellipse[@class="ACVI_Left"]')
block.set('style','fill:{}'.format(colors[12]))
block = root.find('{http://www.w3.org/2000/svg}ellipse[@class="ACVI_Right"]')
block.set('style','fill:{}'.format(colors[13]))
block = root.find('{http://www.w3.org/2000/svg}ellipse[@class="ACVII_Left"]')
block.set('style','fill:{}'.format(colors[14]))
block = root.find('{http://www.w3.org/2000/svg}ellipse[@class="ACVII_Right"]')
block.set('style','fill:{}'.format(colors[15]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="AD_Left"]')
block.set('style','fill:{}'.format(colors[16]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="AD_Right"]')
block.set('style','fill:{}'.format(colors[17]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="ADP_Left"]')
block.set('style','fill:{}'.format(colors[18]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="ADP_Right"]')
block.set('style','fill:{}'.format(colors[19]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="AHA_Left"]')
block.set('style','fill:{}'.format(colors[20]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="AHA_Right"]')
block.set('style','fill:{}'.format(colors[21]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="AHNa_Left"]')
block.set('style','fill:{}'.format(colors[22]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="AHNa_Right"]')
block.set('style','fill:{}'.format(colors[23]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="AHNc_Left"]')
block.set('style','fill:{}'.format(colors[24]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="AHNc_Right"]')
block.set('style','fill:{}'.format(colors[25]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="AHNd_Left"]')
block.set('style','fill:{}'.format(colors[26]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="AHNd_Right"]')
block.set('style','fill:{}'.format(colors[27]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="AHNp_Left"]')
block.set('style','fill:{}'.format(colors[28]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="AHNp_Right"]')
block.set('style','fill:{}'.format(colors[29]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="AId_Left"]')
block.set('style','fill:{}'.format(colors[30]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="AId_Right"]')
block.set('style','fill:{}'.format(colors[31]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="AIp_Left"]')
block.set('style','fill:{}'.format(colors[32]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="AIp_Right"]')
block.set('style','fill:{}'.format(colors[33]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="AIv_Left"]')
block.set('style','fill:{}'.format(colors[34]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="AIv_Right"]')
block.set('style','fill:{}'.format(colors[35]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="AMBd_Left"]')
block.set('style','fill:{}'.format(colors[36]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="AMBd_Right"]')
block.set('style','fill:{}'.format(colors[37]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="AMBv_Left"]')
block.set('style','fill:{}'.format(colors[38]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="AMBv_Right"]')
block.set('style','fill:{}'.format(colors[39]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="AMd_Left"]')
block.set('style','fill:{}'.format(colors[40]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="AMd_Right"]')
block.set('style','fill:{}'.format(colors[41]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="AMv_Left"]')
block.set('style','fill:{}'.format(colors[42]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="AMv_Right"]')
block.set('style','fill:{}'.format(colors[43]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="ANcr1_Left"]')
block.set('style','fill:{}'.format(colors[44]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="ANcr1_Right"]')
block.set('style','fill:{}'.format(colors[45]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="ANcr2_Left"]')
block.set('style','fill:{}'.format(colors[46]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="ANcr2_Right"]')
block.set('style','fill:{}'.format(colors[47]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="AOA_Left"]')
block.set('style','fill:{}'.format(colors[48]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="AOA_Right"]')
block.set('style','fill:{}'.format(colors[49]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="AOB_Left"]')
block.set('style','fill:{}'.format(colors[50]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="AOB_Right"]')
block.set('style','fill:{}'.format(colors[51]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="AP_Left"]')
block.set('style','fill:{}'.format(colors[52]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="AP_Right"]')
block.set('style','fill:{}'.format(colors[53]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="APN_Left"]')
block.set('style','fill:{}'.format(colors[54]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="APN_Right"]')
block.set('style','fill:{}'.format(colors[55]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="ARH_Left"]')
block.set('style','fill:{}'.format(colors[56]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="ARH_Right"]')
block.set('style','fill:{}'.format(colors[57]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="AT_Left"]')
block.set('style','fill:{}'.format(colors[58]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="AT_Right"]')
block.set('style','fill:{}'.format(colors[59]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="AUDd_Left"]')
block.set('style','fill:{}'.format(colors[60]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="AUDd_Right"]')
block.set('style','fill:{}'.format(colors[61]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="AUDp_Left"]')
block.set('style','fill:{}'.format(colors[62]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="AUDp_Right"]')
block.set('style','fill:{}'.format(colors[63]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="AUDpo_Left"]')
block.set('style','fill:{}'.format(colors[64]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="AUDpo_Right"]')
block.set('style','fill:{}'.format(colors[65]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="AUDv_Left"]')
block.set('style','fill:{}'.format(colors[66]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="AUDv_Right"]')
block.set('style','fill:{}'.format(colors[67]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="AV_Left"]')
block.set('style','fill:{}'.format(colors[68]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="AV_Right"]')
block.set('style','fill:{}'.format(colors[69]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="AVP_Left"]')
block.set('style','fill:{}'.format(colors[70]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="AVP_Right"]')
block.set('style','fill:{}'.format(colors[71]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="AVPV_Left"]')
block.set('style','fill:{}'.format(colors[72]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="AVPV_Right"]')
block.set('style','fill:{}'.format(colors[73]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="B_Left"]')
block.set('style','fill:{}'.format(colors[74]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="B_Right"]')
block.set('style','fill:{}'.format(colors[75]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="BA_Left"]')
block.set('style','fill:{}'.format(colors[76]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="BA_Right"]')
block.set('style','fill:{}'.format(colors[77]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="BAC_Left"]')
block.set('style','fill:{}'.format(colors[78]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="BAC_Right"]')
block.set('style','fill:{}'.format(colors[79]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="BLAa_Left"]')
block.set('style','fill:{}'.format(colors[80]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="BLAa_Right"]')
block.set('style','fill:{}'.format(colors[81]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="BLAp_Left"]')
block.set('style','fill:{}'.format(colors[82]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="BLAp_Right"]')
block.set('style','fill:{}'.format(colors[83]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="BMAa_Left"]')
block.set('style','fill:{}'.format(colors[84]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="BMAa_Right"]')
block.set('style','fill:{}'.format(colors[85]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="BMAp_Left"]')
block.set('style','fill:{}'.format(colors[86]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="BMAp_Right"]')
block.set('style','fill:{}'.format(colors[87]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="BN_Left"]')
block.set('style','fill:{}'.format(colors[88]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="BN_Right"]')
block.set('style','fill:{}'.format(colors[89]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="BSTal_Left"]')
block.set('style','fill:{}'.format(colors[90]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="BSTal_Right"]')
block.set('style','fill:{}'.format(colors[91]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="BSTam_Left"]')
block.set('style','fill:{}'.format(colors[92]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="BSTam_Right"]')
block.set('style','fill:{}'.format(colors[93]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="BSTd_Left"]')
block.set('style','fill:{}'.format(colors[94]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="BSTd_Right"]')
block.set('style','fill:{}'.format(colors[95]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="BSTdm_Left"]')
block.set('style','fill:{}'.format(colors[96]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="BSTdm_Right"]')
block.set('style','fill:{}'.format(colors[97]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="BSTfu_Left"]')
block.set('style','fill:{}'.format(colors[98]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="BSTfu_Right"]')
block.set('style','fill:{}'.format(colors[99]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="BSTif_Left"]')
block.set('style','fill:{}'.format(colors[100]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="BSTif_Right"]')
block.set('style','fill:{}'.format(colors[101]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="BSTju_Left"]')
block.set('style','fill:{}'.format(colors[102]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="BSTju_Right"]')
block.set('style','fill:{}'.format(colors[103]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="BSTmg_Left"]')
block.set('style','fill:{}'.format(colors[104]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="BSTmg_Right"]')
block.set('style','fill:{}'.format(colors[105]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="BSTov_Left"]')
block.set('style','fill:{}'.format(colors[106]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="BSTov_Right"]')
block.set('style','fill:{}'.format(colors[107]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="BSTpr_Left"]')
block.set('style','fill:{}'.format(colors[108]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="BSTpr_Right"]')
block.set('style','fill:{}'.format(colors[109]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="BSTrh_Left"]')
block.set('style','fill:{}'.format(colors[110]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="BSTrh_Right"]')
block.set('style','fill:{}'.format(colors[111]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="BSTse_Left"]')
block.set('style','fill:{}'.format(colors[112]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="BSTse_Right"]')
block.set('style','fill:{}'.format(colors[113]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="BSTtr_Left"]')
block.set('style','fill:{}'.format(colors[114]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="BSTtr_Right"]')
block.set('style','fill:{}'.format(colors[115]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="BSTv_Left"]')
block.set('style','fill:{}'.format(colors[116]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="BSTv_Right"]')
block.set('style','fill:{}'.format(colors[117]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="CA1d_Left"]')
block.set('style','fill:{}'.format(colors[118]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="CA1d_Right"]')
block.set('style','fill:{}'.format(colors[119]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="CA1v_Left"]')
block.set('style','fill:{}'.format(colors[120]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="CA1v_Right"]')
block.set('style','fill:{}'.format(colors[121]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="CA2_Left"]')
block.set('style','fill:{}'.format(colors[122]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="CA2_Right"]')
block.set('style','fill:{}'.format(colors[123]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="CA3_Left"]')
block.set('style','fill:{}'.format(colors[124]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="CA3_Right"]')
block.set('style','fill:{}'.format(colors[125]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="CEAc_Left"]')
block.set('style','fill:{}'.format(colors[126]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="CEAc_Right"]')
block.set('style','fill:{}'.format(colors[127]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="CEAl_Left"]')
block.set('style','fill:{}'.format(colors[128]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="CEAl_Right"]')
block.set('style','fill:{}'.format(colors[129]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="CEAm_Left"]')
block.set('style','fill:{}'.format(colors[130]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="CEAm_Right"]')
block.set('style','fill:{}'.format(colors[131]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="CEC_Left"]')
block.set('style','fill:{}'.format(colors[132]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="CEC_Right"]')
block.set('style','fill:{}'.format(colors[133]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="CENT_Left"]')
block.set('style','fill:{}'.format(colors[134]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="CENT_Right"]')
block.set('style','fill:{}'.format(colors[135]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="CL_Left"]')
block.set('style','fill:{}'.format(colors[136]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="CL_Right"]')
block.set('style','fill:{}'.format(colors[137]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="CLA_Left"]')
block.set('style','fill:{}'.format(colors[138]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="CLA_Right"]')
block.set('style','fill:{}'.format(colors[139]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="CLI_Left"]')
block.set('style','fill:{}'.format(colors[140]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="CLI_Right"]')
block.set('style','fill:{}'.format(colors[141]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="CM_Left"]')
block.set('style','fill:{}'.format(colors[142]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="CM_Right"]')
block.set('style','fill:{}'.format(colors[143]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="CNlam_Left"]')
block.set('style','fill:{}'.format(colors[144]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="CNlam_Right"]')
block.set('style','fill:{}'.format(colors[145]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="CNspg_Left"]')
block.set('style','fill:{}'.format(colors[146]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="CNspg_Right"]')
block.set('style','fill:{}'.format(colors[147]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="COAa_Left"]')
block.set('style','fill:{}'.format(colors[148]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="COAa_Right"]')
block.set('style','fill:{}'.format(colors[149]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="COApl_Left"]')
block.set('style','fill:{}'.format(colors[150]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="COApl_Right"]')
block.set('style','fill:{}'.format(colors[151]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="COApm_Left"]')
block.set('style','fill:{}'.format(colors[152]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="COApm_Right"]')
block.set('style','fill:{}'.format(colors[153]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="COM_Left"]')
block.set('style','fill:{}'.format(colors[154]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="COM_Right"]')
block.set('style','fill:{}'.format(colors[155]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="COPY_Left"]')
block.set('style','fill:{}'.format(colors[156]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="COPY_Right"]')
block.set('style','fill:{}'.format(colors[157]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="CP_Left"]')
block.set('style','fill:{}'.format(colors[158]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="CP_Right"]')
block.set('style','fill:{}'.format(colors[159]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="CS_Left"]')
block.set('style','fill:{}'.format(colors[160]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="CS_Right"]')
block.set('style','fill:{}'.format(colors[161]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="CU_Left"]')
block.set('style','fill:{}'.format(colors[162]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="CU_Right"]')
block.set('style','fill:{}'.format(colors[163]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="CUL_or_LIV_V_Left"]')
block.set('style','fill:{}'.format(colors[164]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="CUL_or_LIV_V_Right"]')
block.set('style','fill:{}'.format(colors[165]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="CUN_Left"]')
block.set('style','fill:{}'.format(colors[166]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="CUN_Right"]')
block.set('style','fill:{}'.format(colors[167]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="DCO_Left"]')
block.set('style','fill:{}'.format(colors[168]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="DCO_Right"]')
block.set('style','fill:{}'.format(colors[169]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="DEC_or_LVI_Left"]')
block.set('style','fill:{}'.format(colors[170]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="DEC_or_LVI_Right"]')
block.set('style','fill:{}'.format(colors[171]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="DG_Left"]')
block.set('style','fill:{}'.format(colors[172]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="DG_Right"]')
block.set('style','fill:{}'.format(colors[173]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="DMHa_Left"]')
block.set('style','fill:{}'.format(colors[174]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="DMHa_Right"]')
block.set('style','fill:{}'.format(colors[175]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="DMHp_Left"]')
block.set('style','fill:{}'.format(colors[176]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="DMHp_Right"]')
block.set('style','fill:{}'.format(colors[177]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="DMHv_Left"]')
block.set('style','fill:{}'.format(colors[178]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="DMHv_Right"]')
block.set('style','fill:{}'.format(colors[179]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="DMX_Left"]')
block.set('style','fill:{}'.format(colors[180]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="DMX_Right"]')
block.set('style','fill:{}'.format(colors[181]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="DNm_Left"]')
block.set('style','fill:{}'.format(colors[182]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="DNm_Right"]')
block.set('style','fill:{}'.format(colors[183]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="DNp_Left"]')
block.set('style','fill:{}'.format(colors[184]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="DNp_Right"]')
block.set('style','fill:{}'.format(colors[185]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="DOC_Left"]')
block.set('style','fill:{}'.format(colors[186]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="DOC_Right"]')
block.set('style','fill:{}'.format(colors[187]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="DR_Left"]')
block.set('style','fill:{}'.format(colors[188]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="DR_Right"]')
block.set('style','fill:{}'.format(colors[189]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="DT_Left"]')
block.set('style','fill:{}'.format(colors[190]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="DT_Right"]')
block.set('style','fill:{}'.format(colors[191]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="DTHc_Left"]')
block.set('style','fill:{}'.format(colors[192]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="DTHc_Right"]')
block.set('style','fill:{}'.format(colors[193]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="DTHr_Left"]')
block.set('style','fill:{}'.format(colors[194]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="DTHr_Right"]')
block.set('style','fill:{}'.format(colors[195]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="DTN_Left"]')
block.set('style','fill:{}'.format(colors[196]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="DTN_Right"]')
block.set('style','fill:{}'.format(colors[197]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="ECT_Left"]')
block.set('style','fill:{}'.format(colors[198]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="ECT_Right"]')
block.set('style','fill:{}'.format(colors[199]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="ENTl_Left"]')
block.set('style','fill:{}'.format(colors[200]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="ENTl_Right"]')
block.set('style','fill:{}'.format(colors[201]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="ENTm_Left"]')
block.set('style','fill:{}'.format(colors[202]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="ENTm_Right"]')
block.set('style','fill:{}'.format(colors[203]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="EPd_Left"]')
block.set('style','fill:{}'.format(colors[204]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="EPd_Right"]')
block.set('style','fill:{}'.format(colors[205]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="EPv_Left"]')
block.set('style','fill:{}'.format(colors[206]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="EPv_Right"]')
block.set('style','fill:{}'.format(colors[207]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="EV_Left"]')
block.set('style','fill:{}'.format(colors[208]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="EV_Right"]')
block.set('style','fill:{}'.format(colors[209]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="EW_Left"]')
block.set('style','fill:{}'.format(colors[210]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="EW_Right"]')
block.set('style','fill:{}'.format(colors[211]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="FC_Left"]')
block.set('style','fill:{}'.format(colors[212]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="FC_Right"]')
block.set('style','fill:{}'.format(colors[213]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="FF_Left"]')
block.set('style','fill:{}'.format(colors[214]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="FF_Right"]')
block.set('style','fill:{}'.format(colors[215]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="FL_Left"]')
block.set('style','fill:{}'.format(colors[216]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="FL_Right"]')
block.set('style','fill:{}'.format(colors[217]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="FN_Left"]')
block.set('style','fill:{}'.format(colors[218]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="FN_Right"]')
block.set('style','fill:{}'.format(colors[219]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="FOTU_or_LVII_Left"]')
block.set('style','fill:{}'.format(colors[220]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="FOTU_or_LVII_Right"]')
block.set('style','fill:{}'.format(colors[221]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="FS_Left"]')
block.set('style','fill:{}'.format(colors[222]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="FS_Right"]')
block.set('style','fill:{}'.format(colors[223]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="GES_Left"]')
block.set('style','fill:{}'.format(colors[224]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="GES_Right"]')
block.set('style','fill:{}'.format(colors[225]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="GPl_Left"]')
block.set('style','fill:{}'.format(colors[226]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="GPl_Right"]')
block.set('style','fill:{}'.format(colors[227]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="GPm_Left"]')
block.set('style','fill:{}'.format(colors[228]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="GPm_Right"]')
block.set('style','fill:{}'.format(colors[229]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="GR_Left"]')
block.set('style','fill:{}'.format(colors[230]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="GR_Right"]')
block.set('style','fill:{}'.format(colors[231]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="GRN_Left"]')
block.set('style','fill:{}'.format(colors[232]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="GRN_Right"]')
block.set('style','fill:{}'.format(colors[233]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="GU_Left"]')
block.set('style','fill:{}'.format(colors[234]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="GU_Right"]')
block.set('style','fill:{}'.format(colors[235]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="I_caudal_tile_Left"]')
block.set('style','fill:{}'.format(colors[236])) #I_caudal_tile_Left=I_rostral_tile_Left
block = root.find('{http://www.w3.org/2000/svg}path[@class="I_caudal_tile_Right"]')
block.set('style','fill:{}'.format(colors[237])) #I_caudal_tile_Right=I_rostral_tile_Right
block = root.find('{http://www.w3.org/2000/svg}path[@class="I_rostral_tile_Left"]')
block.set('style','fill:{}'.format(colors[236])) #I_caudal_tile_Left=I_rostral_tile_Left
block = root.find('{http://www.w3.org/2000/svg}path[@class="I_rostral_tile_Right"]')
block.set('style','fill:{}'.format(colors[237])) #I_caudal_tile_Left=I_rostral_tile_Right
block = root.find('{http://www.w3.org/2000/svg}path[@class="IA_Left"]')
block.set('style','fill:{}'.format(colors[238]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="IA_Right"]')
block.set('style','fill:{}'.format(colors[239]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="IAD_Left"]')
block.set('style','fill:{}'.format(colors[240]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="IAD_Right"]')
block.set('style','fill:{}'.format(colors[241]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="IAM_Left"]')
block.set('style','fill:{}'.format(colors[242]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="IAM_Right"]')
block.set('style','fill:{}'.format(colors[243]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="IAN_Left"]')
block.set('style','fill:{}'.format(colors[244]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="IAN_Right"]')
block.set('style','fill:{}'.format(colors[245]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="ICB_Left"]')
block.set('style','fill:{}'.format(colors[246]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="ICB_Right"]')
block.set('style','fill:{}'.format(colors[247]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="ICc_Left"]')
block.set('style','fill:{}'.format(colors[248]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="ICc_Right"]')
block.set('style','fill:{}'.format(colors[249]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="ICd_Left"]')
block.set('style','fill:{}'.format(colors[250]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="ICd_Right"]')
block.set('style','fill:{}'.format(colors[251]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="ICe_Left"]')
block.set('style','fill:{}'.format(colors[252]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="ICe_Right"]')
block.set('style','fill:{}'.format(colors[253]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="ICS_Left"]')
block.set('style','fill:{}'.format(colors[254]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="ICS_Right"]')
block.set('style','fill:{}'.format(colors[255]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="IF_Left"]')
block.set('style','fill:{}'.format(colors[256]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="IF_Right"]')
block.set('style','fill:{}'.format(colors[257]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="IG_Left"]')
block.set('style','fill:{}'.format(colors[258]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="IG_Right"]')
block.set('style','fill:{}'.format(colors[259]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="IGL_Left"]')
block.set('style','fill:{}'.format(colors[260]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="IGL_Right"]')
block.set('style','fill:{}'.format(colors[261]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="III_Left"]')
block.set('style','fill:{}'.format(colors[262]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="III_Right"]')
block.set('style','fill:{}'.format(colors[263]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="ILA_Left"]')
block.set('style','fill:{}'.format(colors[264]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="ILA_Right"]')
block.set('style','fill:{}'.format(colors[265]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="IMD_Left"]')
block.set('style','fill:{}'.format(colors[266]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="IMD_Right"]')
block.set('style','fill:{}'.format(colors[267]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="IMLsa_Left"]')
block.set('style','fill:{}'.format(colors[268]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="IMLsa_Right"]')
block.set('style','fill:{}'.format(colors[269]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="IMLtl_Left"]')
block.set('style','fill:{}'.format(colors[270]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="IMLtl_Right"]')
block.set('style','fill:{}'.format(colors[271]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="IMM_Left"]')
block.set('style','fill:{}'.format(colors[272]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="IMM_Right"]')
block.set('style','fill:{}'.format(colors[273]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="INC_Left"]')
block.set('style','fill:{}'.format(colors[274]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="INC_Right"]')
block.set('style','fill:{}'.format(colors[275]))
block = root.find('{http://www.w3.org/2000/svg}ellipse[@class="INV_Left"]')
block.set('style','fill:{}'.format(colors[276]))
block = root.find('{http://www.w3.org/2000/svg}ellipse[@class="INV_Right"]')
block.set('style','fill:{}'.format(colors[277]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="IOda_Left"]')
block.set('style','fill:{}'.format(colors[278]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="IOda_Right"]')
block.set('style','fill:{}'.format(colors[279]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="IOma_Left"]')
block.set('style','fill:{}'.format(colors[280]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="IOma_Right"]')
block.set('style','fill:{}'.format(colors[281]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="IOpr_Left"]')
block.set('style','fill:{}'.format(colors[282]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="IOpr_Right"]')
block.set('style','fill:{}'.format(colors[283]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="IPN_Left"]')
block.set('style','fill:{}'.format(colors[284]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="IPN_Right"]')
block.set('style','fill:{}'.format(colors[285]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="IPpc_Left"]')
block.set('style','fill:{}'.format(colors[286]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="IPpc_Right"]')
block.set('style','fill:{}'.format(colors[287]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="IPpr_Left"]')
block.set('style','fill:{}'.format(colors[288]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="IPpr_Right"]')
block.set('style','fill:{}'.format(colors[289]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="ISN_Left"]')
block.set('style','fill:{}'.format(colors[290]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="ISN_Right"]')
block.set('style','fill:{}'.format(colors[291]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="IV_Left"]')
block.set('style','fill:{}'.format(colors[292]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="IV_Right"]')
block.set('style','fill:{}'.format(colors[293]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="IZp_Left"]')
block.set('style','fill:{}'.format(colors[294]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="IZp_Right"]')
block.set('style','fill:{}'.format(colors[295]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="KF_Left"]')
block.set('style','fill:{}'.format(colors[296]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="KF_Right"]')
block.set('style','fill:{}'.format(colors[297]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="LA_Left"]')
block.set('style','fill:{}'.format(colors[298]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="LA_Right"]')
block.set('style','fill:{}'.format(colors[299]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="LAV_Left"]')
block.set('style','fill:{}'.format(colors[300]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="LAV_Right"]')
block.set('style','fill:{}'.format(colors[301]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="LC_Left"]')
block.set('style','fill:{}'.format(colors[302]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="LC_Right"]')
block.set('style','fill:{}'.format(colors[303]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="LCN_Left"]')
block.set('style','fill:{}'.format(colors[304]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="LCN_Right"]')
block.set('style','fill:{}'.format(colors[305]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="LD_Left"]')
block.set('style','fill:{}'.format(colors[306]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="LD_Right"]')
block.set('style','fill:{}'.format(colors[307]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="LDT_Left"]')
block.set('style','fill:{}'.format(colors[308]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="LDT_Right"]')
block.set('style','fill:{}'.format(colors[309]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="LGd_Left"]')
block.set('style','fill:{}'.format(colors[310]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="LGd_Right"]')
block.set('style','fill:{}'.format(colors[311]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="LGv_Left"]')
block.set('style','fill:{}'.format(colors[312]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="LGv_Right"]')
block.set('style','fill:{}'.format(colors[313]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="LH_Left"]')
block.set('style','fill:{}'.format(colors[314]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="LH_Right"]')
block.set('style','fill:{}'.format(colors[315]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="LHAa_Left"]')
block.set('style','fill:{}'.format(colors[316]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="LHAa_Right"]')
block.set('style','fill:{}'.format(colors[317]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="LHAd_Left"]')
block.set('style','fill:{}'.format(colors[318]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="LHAd_Right"]')
block.set('style','fill:{}'.format(colors[319]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="LHAjd_Left"]')
block.set('style','fill:{}'.format(colors[320]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="LHAjd_Right"]')
block.set('style','fill:{}'.format(colors[321]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="LHAjp_Left"]')
block.set('style','fill:{}'.format(colors[322]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="LHAjp_Right"]')
block.set('style','fill:{}'.format(colors[323]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="LHAjvd_Left"]')
block.set('style','fill:{}'.format(colors[324]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="LHAjvd_Right"]')
block.set('style','fill:{}'.format(colors[325]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="LHAjvv_Left"]')
block.set('style','fill:{}'.format(colors[326]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="LHAjvv_Right"]')
block.set('style','fill:{}'.format(colors[327]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="LHAp_Left"]')
block.set('style','fill:{}'.format(colors[328]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="LHAp_Right"]')
block.set('style','fill:{}'.format(colors[329]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="LHAs_Left"]')
block.set('style','fill:{}'.format(colors[330]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="LHAs_Right"]')
block.set('style','fill:{}'.format(colors[331]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="LHAsfa_Left"]')
block.set('style','fill:{}'.format(colors[332]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="LHAsfa_Right"]')
block.set('style','fill:{}'.format(colors[333]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="LHAsfp_Left"]')
block.set('style','fill:{}'.format(colors[334]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="LHAsfp_Right"]')
block.set('style','fill:{}'.format(colors[335]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="LHAv_Left"]')
block.set('style','fill:{}'.format(colors[336]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="LHAv_Right"]')
block.set('style','fill:{}'.format(colors[337]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="LIN_Left"]')
block.set('style','fill:{}'.format(colors[338]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="LIN_Right"]')
block.set('style','fill:{}'.format(colors[339]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="LING_or_LI_Left"]')
block.set('style','fill:{}'.format(colors[340]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="LING_or_LI_Right"]')
block.set('style','fill:{}'.format(colors[341]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="LM_Left"]')
block.set('style','fill:{}'.format(colors[342]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="LM_Right"]')
block.set('style','fill:{}'.format(colors[343]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="LP_Left"]')
block.set('style','fill:{}'.format(colors[344]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="LP_Right"]')
block.set('style','fill:{}'.format(colors[345]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="LPO_Left"]')
block.set('style','fill:{}'.format(colors[346]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="LPO_Right"]')
block.set('style','fill:{}'.format(colors[347]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="LRNm_Left"]')
block.set('style','fill:{}'.format(colors[348]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="LRNm_Right"]')
block.set('style','fill:{}'.format(colors[349]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="LRNp_Left"]')
block.set('style','fill:{}'.format(colors[350]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="LRNp_Right"]')
block.set('style','fill:{}'.format(colors[351]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="LSc.d_Left"]')
block.set('style','fill:{}'.format(colors[352]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="LSc.d_Right"]')
block.set('style','fill:{}'.format(colors[353]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="LSc.v_Left"]')
block.set('style','fill:{}'.format(colors[354]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="LSc.v_Right"]')
block.set('style','fill:{}'.format(colors[355]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="LSN_Left"]')
block.set('style','fill:{}'.format(colors[356]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="LSN_Right"]')
block.set('style','fill:{}'.format(colors[357]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="LSr.dl_Left"]')
block.set('style','fill:{}'.format(colors[358]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="LSr.dl_Right"]')
block.set('style','fill:{}'.format(colors[359]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="LSr.m.d_Left"]')
block.set('style','fill:{}'.format(colors[360]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="LSr.m.d_Right"]')
block.set('style','fill:{}'.format(colors[361]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="LSr.m.v_Left"]')
block.set('style','fill:{}'.format(colors[362]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="LSr.m.v_Right"]')
block.set('style','fill:{}'.format(colors[363]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="LSr.vl_Left"]')
block.set('style','fill:{}'.format(colors[364]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="LSr.vl_Right"]')
block.set('style','fill:{}'.format(colors[365]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="LSv_Left"]')
block.set('style','fill:{}'.format(colors[366]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="LSv_Right"]')
block.set('style','fill:{}'.format(colors[367]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="LT_Left"]')
block.set('style','fill:{}'.format(colors[368]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="LT_Right"]')
block.set('style','fill:{}'.format(colors[369]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="LTN_Left"]')
block.set('style','fill:{}'.format(colors[370]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="LTN_Right"]')
block.set('style','fill:{}'.format(colors[371]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="MA_Left"]')
block.set('style','fill:{}'.format(colors[372]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="MA_Right"]')
block.set('style','fill:{}'.format(colors[373]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="MAN_Left"]')
block.set('style','fill:{}'.format(colors[374]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="MAN_Right"]')
block.set('style','fill:{}'.format(colors[375]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="MARN_Left"]')
block.set('style','fill:{}'.format(colors[376]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="MARN_Right"]')
block.set('style','fill:{}'.format(colors[377]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="MDc_Left"]')
block.set('style','fill:{}'.format(colors[378]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="MDc_Right"]')
block.set('style','fill:{}'.format(colors[379]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="MDl_Left"]')
block.set('style','fill:{}'.format(colors[380]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="MDl_Right"]')
block.set('style','fill:{}'.format(colors[381]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="MDm_Left"]')
block.set('style','fill:{}'.format(colors[382]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="MDm_Right"]')
block.set('style','fill:{}'.format(colors[383]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="MDRNd_Left"]')
block.set('style','fill:{}'.format(colors[384]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="MDRNd_Right"]')
block.set('style','fill:{}'.format(colors[385]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="MDRNv_Left"]')
block.set('style','fill:{}'.format(colors[386]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="MDRNv_Right"]')
block.set('style','fill:{}'.format(colors[387]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="MEAad_Left"]')
block.set('style','fill:{}'.format(colors[388]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="MEAad_Right"]')
block.set('style','fill:{}'.format(colors[389]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="MEAav_Left"]')
block.set('style','fill:{}'.format(colors[390]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="MEAav_Right"]')
block.set('style','fill:{}'.format(colors[391]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="MEApd_Left"]')
block.set('style','fill:{}'.format(colors[392]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="MEApd_Right"]')
block.set('style','fill:{}'.format(colors[393]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="MEApv_Left"]')
block.set('style','fill:{}'.format(colors[394]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="MEApv_Right"]')
block.set('style','fill:{}'.format(colors[395]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="MEPO_Left"]')
block.set('style','fill:{}'.format(colors[396]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="MEPO_Right"]')
block.set('style','fill:{}'.format(colors[397]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="MEV_Left"]')
block.set('style','fill:{}'.format(colors[398]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="MEV_Right"]')
block.set('style','fill:{}'.format(colors[399]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="MGd_Left"]')
block.set('style','fill:{}'.format(colors[400]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="MGd_Right"]')
block.set('style','fill:{}'.format(colors[401]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="MGm_Left"]')
block.set('style','fill:{}'.format(colors[402]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="MGm_Right"]')
block.set('style','fill:{}'.format(colors[403]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="MGv_Left"]')
block.set('style','fill:{}'.format(colors[404]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="MGv_Right"]')
block.set('style','fill:{}'.format(colors[405]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="MH_Left"]')
block.set('style','fill:{}'.format(colors[406]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="MH_Right"]')
block.set('style','fill:{}'.format(colors[407]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="MM_Left"]')
block.set('style','fill:{}'.format(colors[408]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="MM_Right"]')
block.set('style','fill:{}'.format(colors[409]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="MOB_Left"]')
block.set('style','fill:{}'.format(colors[410]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="MOB_Right"]')
block.set('style','fill:{}'.format(colors[411]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="MOp_Left"]')
block.set('style','fill:{}'.format(colors[412]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="MOp_Right"]')
block.set('style','fill:{}'.format(colors[413]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="MOs_Left"]')
block.set('style','fill:{}'.format(colors[414]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="MOs_Right"]')
block.set('style','fill:{}'.format(colors[415]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="MPNc_Left"]')
block.set('style','fill:{}'.format(colors[416]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="MPNc_Right"]')
block.set('style','fill:{}'.format(colors[417]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="MPNl_Left"]')
block.set('style','fill:{}'.format(colors[418]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="MPNl_Right"]')
block.set('style','fill:{}'.format(colors[419]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="MPNm_Left"]')
block.set('style','fill:{}'.format(colors[420]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="MPNm_Right"]')
block.set('style','fill:{}'.format(colors[421]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="MPO_Left"]')
block.set('style','fill:{}'.format(colors[422]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="MPO_Right"]')
block.set('style','fill:{}'.format(colors[423]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="MPT_Left"]')
block.set('style','fill:{}'.format(colors[424]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="MPT_Right"]')
block.set('style','fill:{}'.format(colors[425]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="MRNm_Left"]')
block.set('style','fill:{}'.format(colors[426]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="MRNm_Right"]')
block.set('style','fill:{}'.format(colors[427]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="MRNp_Left"]')
block.set('style','fill:{}'.format(colors[428]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="MRNp_Right"]')
block.set('style','fill:{}'.format(colors[429]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="MS_Left"]')
block.set('style','fill:{}'.format(colors[430]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="MS_Right"]')
block.set('style','fill:{}'.format(colors[431]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="MT_Left"]')
block.set('style','fill:{}'.format(colors[432]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="MT_Right"]')
block.set('style','fill:{}'.format(colors[433]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="MV_Left"]')
block.set('style','fill:{}'.format(colors[434]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="MV_Right"]')
block.set('style','fill:{}'.format(colors[435]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="MZ_Left"]')
block.set('style','fill:{}'.format(colors[436]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="MZ_Right"]')
block.set('style','fill:{}'.format(colors[437]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="NB_Left"]')
block.set('style','fill:{}'.format(colors[438]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="NB_Right"]')
block.set('style','fill:{}'.format(colors[439]))
block = root.find('{http://www.w3.org/2000/svg}ellipse[@class="NBC_Left"]')
block.set('style','fill:{}'.format(colors[440]))
block = root.find('{http://www.w3.org/2000/svg}ellipse[@class="NBC_Right"]')
block.set('style','fill:{}'.format(colors[441]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="ND_Left"]')
block.set('style','fill:{}'.format(colors[442]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="ND_Right"]')
block.set('style','fill:{}'.format(colors[443]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="NDB_Left"]')
block.set('style','fill:{}'.format(colors[444]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="NDB_Right"]')
block.set('style','fill:{}'.format(colors[445]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="NI_Left"]')
block.set('style','fill:{}'.format(colors[446]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="NI_Right"]')
block.set('style','fill:{}'.format(colors[447]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="NIS_Left"]')
block.set('style','fill:{}'.format(colors[448]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="NIS_Right"]')
block.set('style','fill:{}'.format(colors[449]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="NLL_Left"]')
block.set('style','fill:{}'.format(colors[450]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="NLL_Right"]')
block.set('style','fill:{}'.format(colors[451]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="NLOT_Left"]')
block.set('style','fill:{}'.format(colors[452]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="NLOT_Right"]')
block.set('style','fill:{}'.format(colors[453]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="NLOT3_Left"]')
block.set('style','fill:{}'.format(colors[454]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="NLOT3_Right"]')
block.set('style','fill:{}'.format(colors[455]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="NOD_or_LX_Left"]')
block.set('style','fill:{}'.format(colors[456]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="NOD_or_LX_Right"]')
block.set('style','fill:{}'.format(colors[457]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="NOT_Left"]')
block.set('style','fill:{}'.format(colors[458]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="NOT_Right"]')
block.set('style','fill:{}'.format(colors[459]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="NP_Left"]')
block.set('style','fill:{}'.format(colors[460]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="NP_Right"]')
block.set('style','fill:{}'.format(colors[461]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="NPC_Left"]')
block.set('style','fill:{}'.format(colors[462]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="NPC_Right"]')
block.set('style','fill:{}'.format(colors[463]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="NR_Left"]')
block.set('style','fill:{}'.format(colors[464]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="NR_Right"]')
block.set('style','fill:{}'.format(colors[465]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="NTB_Left"]')
block.set('style','fill:{}'.format(colors[466]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="NTB_Right"]')
block.set('style','fill:{}'.format(colors[467]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="NTSco_Left"]')
block.set('style','fill:{}'.format(colors[468]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="NTSco_Right"]')
block.set('style','fill:{}'.format(colors[469]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="NTSl_Left"]')
block.set('style','fill:{}'.format(colors[470]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="NTSl_Right"]')
block.set('style','fill:{}'.format(colors[471]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="NTSmcg_Left"]')
block.set('style','fill:{}'.format(colors[472]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="NTSmcg_Right"]')
block.set('style','fill:{}'.format(colors[473]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="NTSmr_Left"]')
block.set('style','fill:{}'.format(colors[474]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="NTSmr_Right"]')
block.set('style','fill:{}'.format(colors[475]))
block = root.find('{http://www.w3.org/2000/svg}ellipse[@class="ON_Left"]')
block.set('style','fill:{}'.format(colors[476]))
block = root.find('{http://www.w3.org/2000/svg}ellipse[@class="ON_Right"]')
block.set('style','fill:{}'.format(colors[477]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="OP_Left"]')
block.set('style','fill:{}'.format(colors[478]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="OP_Right"]')
block.set('style','fill:{}'.format(colors[479]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="ORBl_Left"]')
block.set('style','fill:{}'.format(colors[480]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="ORBl_Right"]')
block.set('style','fill:{}'.format(colors[481]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="ORBm_Left"]')
block.set('style','fill:{}'.format(colors[482]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="ORBm_Right"]')
block.set('style','fill:{}'.format(colors[483]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="ORBv_Left"]')
block.set('style','fill:{}'.format(colors[484]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="ORBv_Right"]')
block.set('style','fill:{}'.format(colors[485]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="ORBvl_Left"]')
block.set('style','fill:{}'.format(colors[486]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="ORBvl_Right"]')
block.set('style','fill:{}'.format(colors[487]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="OT_Left"]')
block.set('style','fill:{}'.format(colors[488]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="OT_Right"]')
block.set('style','fill:{}'.format(colors[489]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="OV_Left"]')
block.set('style','fill:{}'.format(colors[490]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="OV_Right"]')
block.set('style','fill:{}'.format(colors[491]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="PA_Left"]')
block.set('style','fill:{}'.format(colors[492]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="PA_Right"]')
block.set('style','fill:{}'.format(colors[493]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="PAA_Left"]')
block.set('style','fill:{}'.format(colors[494]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="PAA_Right"]')
block.set('style','fill:{}'.format(colors[495]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="PAGdl_Left"]')
block.set('style','fill:{}'.format(colors[496]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="PAGdl_Right"]')
block.set('style','fill:{}'.format(colors[497]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="PAGdm_Left"]')
block.set('style','fill:{}'.format(colors[498]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="PAGdm_Right"]')
block.set('style','fill:{}'.format(colors[499]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="PAGl_Left"]')
block.set('style','fill:{}'.format(colors[500]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="PAGl_Right"]')
block.set('style','fill:{}'.format(colors[501]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="PAGm_Left"]')
block.set('style','fill:{}'.format(colors[502]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="PAGm_Right"]')
block.set('style','fill:{}'.format(colors[503]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="PAGrl_Left"]')
block.set('style','fill:{}'.format(colors[504]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="PAGrl_Right"]')
block.set('style','fill:{}'.format(colors[505]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="PAGrm_Left"]')
block.set('style','fill:{}'.format(colors[506]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="PAGrm_Right"]')
block.set('style','fill:{}'.format(colors[507]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="PAGvl_Left"]')
block.set('style','fill:{}'.format(colors[508]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="PAGvl_Right"]')
block.set('style','fill:{}'.format(colors[509]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="PAGvm_Left"]')
block.set('style','fill:{}'.format(colors[510]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="PAGvm_Right"]')
block.set('style','fill:{}'.format(colors[511]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="PAR_Left"]')
block.set('style','fill:{}'.format(colors[512]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="PAR_Right"]')
block.set('style','fill:{}'.format(colors[513]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="PARN_Left"]')
block.set('style','fill:{}'.format(colors[514]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="PARN_Right"]')
block.set('style','fill:{}'.format(colors[515]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="PAS_Left"]')
block.set('style','fill:{}'.format(colors[516]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="PAS_Right"]')
block.set('style','fill:{}'.format(colors[517]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="PAT_Left"]')
block.set('style','fill:{}'.format(colors[518]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="PAT_Right"]')
block.set('style','fill:{}'.format(colors[519]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="PBG_Left"]')
block.set('style','fill:{}'.format(colors[520]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="PBG_Right"]')
block.set('style','fill:{}'.format(colors[521]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="PBlc_Left"]')
block.set('style','fill:{}'.format(colors[522]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="PBlc_Right"]')
block.set('style','fill:{}'.format(colors[523]))
block = root.find('{http://www.w3.org/2000/svg}ellipse[@class="PBld_Left"]')
block.set('style','fill:{}'.format(colors[524]))
block = root.find('{http://www.w3.org/2000/svg}ellipse[@class="PBld_Right"]')
block.set('style','fill:{}'.format(colors[525]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="PBle_Left"]')
block.set('style','fill:{}'.format(colors[526]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="PBle_Right"]')
block.set('style','fill:{}'.format(colors[527]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="PBlex_Left"]')
block.set('style','fill:{}'.format(colors[528]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="PBlex_Right"]')
block.set('style','fill:{}'.format(colors[529]))
block = root.find('{http://www.w3.org/2000/svg}ellipse[@class="PBli_Left"]')
block.set('style','fill:{}'.format(colors[530]))
block = root.find('{http://www.w3.org/2000/svg}ellipse[@class="PBli_Right"]')
block.set('style','fill:{}'.format(colors[531]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="PBls_Left"]')
block.set('style','fill:{}'.format(colors[532]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="PBls_Right"]')
block.set('style','fill:{}'.format(colors[533]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="PBlv_Left"]')
block.set('style','fill:{}'.format(colors[534]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="PBlv_Right"]')
block.set('style','fill:{}'.format(colors[535]))
block = root.find('{http://www.w3.org/2000/svg}ellipse[@class="PBme_Left"]')
block.set('style','fill:{}'.format(colors[536]))
block = root.find('{http://www.w3.org/2000/svg}ellipse[@class="PBme_Right"]')
block.set('style','fill:{}'.format(colors[537]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="PBmm_Left"]')
block.set('style','fill:{}'.format(colors[538]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="PBmm_Right"]')
block.set('style','fill:{}'.format(colors[539]))
block = root.find('{http://www.w3.org/2000/svg}ellipse[@class="PBmv_Left"]')
block.set('style','fill:{}'.format(colors[540]))
block = root.find('{http://www.w3.org/2000/svg}ellipse[@class="PBmv_Right"]')
block.set('style','fill:{}'.format(colors[541]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="PCG_Left"]')
block.set('style','fill:{}'.format(colors[542]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="PCG_Right"]')
block.set('style','fill:{}'.format(colors[543]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="PCN_Left"]')
block.set('style','fill:{}'.format(colors[544]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="PCN_Right"]')
block.set('style','fill:{}'.format(colors[545]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="PD_Left"]')
block.set('style','fill:{}'.format(colors[546]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="PD_Right"]')
block.set('style','fill:{}'.format(colors[547]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="PERI_Left"]')
block.set('style','fill:{}'.format(colors[548]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="PERI_Right"]')
block.set('style','fill:{}'.format(colors[549]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="PF_Left"]')
block.set('style','fill:{}'.format(colors[550]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="PF_Right"]')
block.set('style','fill:{}'.format(colors[551]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="PFL_Left"]')
block.set('style','fill:{}'.format(colors[552]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="PFL_Right"]')
block.set('style','fill:{}'.format(colors[553]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="PGRNd_Left"]')
block.set('style','fill:{}'.format(colors[554]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="PGRNd_Right"]')
block.set('style','fill:{}'.format(colors[555]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="PGRNl_Left"]')
block.set('style','fill:{}'.format(colors[556]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="PGRNl_Right"]')
block.set('style','fill:{}'.format(colors[557]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="PH_Left"]')
block.set('style','fill:{}'.format(colors[558]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="PH_Right"]')
block.set('style','fill:{}'.format(colors[559]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="PIR_Left"]')
block.set('style','fill:{}'.format(colors[560]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="PIR_Right"]')
block.set('style','fill:{}'.format(colors[561]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="PL_Left"]')
block.set('style','fill:{}'.format(colors[562]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="PL_Right"]')
block.set('style','fill:{}'.format(colors[563]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="PMd_Left"]')
block.set('style','fill:{}'.format(colors[564]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="PMd_Right"]')
block.set('style','fill:{}'.format(colors[565]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="PMR_Left"]')
block.set('style','fill:{}'.format(colors[566]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="PMR_Right"]')
block.set('style','fill:{}'.format(colors[567]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="PMv_Left"]')
block.set('style','fill:{}'.format(colors[568]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="PMv_Right"]')
block.set('style','fill:{}'.format(colors[569]))
block = root.find('{http://www.w3.org/2000/svg}ellipse[@class="PN_Left"]')
block.set('style','fill:{}'.format(colors[570]))
block = root.find('{http://www.w3.org/2000/svg}ellipse[@class="PN_Right"]')
block.set('style','fill:{}'.format(colors[571]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="PO_Left"]')
block.set('style','fill:{}'.format(colors[572]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="PO_Right"]')
block.set('style','fill:{}'.format(colors[573]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="POL_Left"]')
block.set('style','fill:{}'.format(colors[574]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="POL_Right"]')
block.set('style','fill:{}'.format(colors[575]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="PON_Left"]')
block.set('style','fill:{}'.format(colors[576]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="PON_Right"]')
block.set('style','fill:{}'.format(colors[577]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="POST_Left"]')
block.set('style','fill:{}'.format(colors[578]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="POST_Right"]')
block.set('style','fill:{}'.format(colors[579]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="PP_Left"]')
block.set('style','fill:{}'.format(colors[580]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="PP_Right"]')
block.set('style','fill:{}'.format(colors[581]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="PPN_Left"]')
block.set('style','fill:{}'.format(colors[582]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="PPN_Right"]')
block.set('style','fill:{}'.format(colors[583]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="PPT_Left"]')
block.set('style','fill:{}'.format(colors[584]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="PPT_Right"]')
block.set('style','fill:{}'.format(colors[585]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="PPY_Left"]')
block.set('style','fill:{}'.format(colors[586]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="PPY_Right"]')
block.set('style','fill:{}'.format(colors[587]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="PR_Left"]')
block.set('style','fill:{}'.format(colors[588]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="PR_Right"]')
block.set('style','fill:{}'.format(colors[589]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="PRC_Left"]')
block.set('style','fill:{}'.format(colors[590]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="PRC_Right"]')
block.set('style','fill:{}'.format(colors[591]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="PRE_Left"]')
block.set('style','fill:{}'.format(colors[592]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="PRE_Right"]')
block.set('style','fill:{}'.format(colors[593]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="PRM_Left"]')
block.set('style','fill:{}'.format(colors[594]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="PRM_Right"]')
block.set('style','fill:{}'.format(colors[595]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="PRNc_Left"]')
block.set('style','fill:{}'.format(colors[596]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="PRNc_Right"]')
block.set('style','fill:{}'.format(colors[597]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="PRNr_Left"]')
block.set('style','fill:{}'.format(colors[598]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="PRNr_Right"]')
block.set('style','fill:{}'.format(colors[599]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="PRP_Left"]')
block.set('style','fill:{}'.format(colors[600]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="PRP_Right"]')
block.set('style','fill:{}'.format(colors[601]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="PS_Left"]')
block.set('style','fill:{}'.format(colors[602]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="PS_Right"]')
block.set('style','fill:{}'.format(colors[603]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="PSCH_Left"]')
block.set('style','fill:{}'.format(colors[604]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="PSCH_Right"]')
block.set('style','fill:{}'.format(colors[605]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="PST_Left"]')
block.set('style','fill:{}'.format(colors[606]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="PST_Right"]')
block.set('style','fill:{}'.format(colors[607]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="PSTN_Left"]')
block.set('style','fill:{}'.format(colors[608]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="PSTN_Right"]')
block.set('style','fill:{}'.format(colors[609]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="PSV_Left"]')
block.set('style','fill:{}'.format(colors[610]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="PSV_Right"]')
block.set('style','fill:{}'.format(colors[611]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="PT_Left"]')
block.set('style','fill:{}'.format(colors[612]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="PT_Right"]')
block.set('style','fill:{}'.format(colors[613]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="PTLp_Left"]')
block.set('style','fill:{}'.format(colors[614]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="PTLp_Right"]')
block.set('style','fill:{}'.format(colors[615]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="PVa_caudal_tile_Left"]')
block.set('style','fill:{}'.format(colors[616])) #PVa_caudal_tile_Left=PVa_rostral_tile_Left
block = root.find('{http://www.w3.org/2000/svg}path[@class="PVa_caudal_tile_Right"]')
block.set('style','fill:{}'.format(colors[617])) #PVa_caudal_tile_Right=PVa_rostral_tile_Right
block = root.find('{http://www.w3.org/2000/svg}path[@class="PVa_rostral_tile_Left"]')
block.set('style','fill:{}'.format(colors[616])) #PVa_caudal_tile_Left=PVa_rostral_tile_Left
block = root.find('{http://www.w3.org/2000/svg}path[@class="PVa_rostral_tile_Right"]')
block.set('style','fill:{}'.format(colors[617])) #PVa_caudal_tile_Right=PVa_rostral_tile_Right
block = root.find('{http://www.w3.org/2000/svg}path[@class="PVHam_Left"]')
block.set('style','fill:{}'.format(colors[618]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="PVHam_Right"]')
block.set('style','fill:{}'.format(colors[619]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="PVHap_Left"]')
block.set('style','fill:{}'.format(colors[620]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="PVHap_Right"]')
block.set('style','fill:{}'.format(colors[621]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="PVHd_Left"]')
block.set('style','fill:{}'.format(colors[622]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="PVHd_Right"]')
block.set('style','fill:{}'.format(colors[623]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="PVHmpd_Left"]')
block.set('style','fill:{}'.format(colors[624]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="PVHmpd_Right"]')
block.set('style','fill:{}'.format(colors[625]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="PVHpm_Left"]')
block.set('style','fill:{}'.format(colors[626]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="PVHpm_Right"]')
block.set('style','fill:{}'.format(colors[627]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="PVHpv_Left"]')
block.set('style','fill:{}'.format(colors[628]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="PVHpv_Right"]')
block.set('style','fill:{}'.format(colors[629]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="PVp_Left"]')
block.set('style','fill:{}'.format(colors[630]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="PVp_Right"]')
block.set('style','fill:{}'.format(colors[631]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="PVT_Left"]')
block.set('style','fill:{}'.format(colors[632]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="PVT_Right"]')
block.set('style','fill:{}'.format(colors[633]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="PYR_or_LVIII_Left"]')
block.set('style','fill:{}'.format(colors[634]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="PYR_or_LVIII_Right"]')
block.set('style','fill:{}'.format(colors[635]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="R_Left"]')
block.set('style','fill:{}'.format(colors[636]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="R_Right"]')
block.set('style','fill:{}'.format(colors[637]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="RCH_Left"]')
block.set('style','fill:{}'.format(colors[638]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="RCH_Right"]')
block.set('style','fill:{}'.format(colors[639]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="REc_Left"]')
block.set('style','fill:{}'.format(colors[640]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="REc_Right"]')
block.set('style','fill:{}'.format(colors[641]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="REr_Left"]')
block.set('style','fill:{}'.format(colors[642]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="REr_Right"]')
block.set('style','fill:{}'.format(colors[643]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="RH_Left"]')
block.set('style','fill:{}'.format(colors[644]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="RH_Right"]')
block.set('style','fill:{}'.format(colors[645]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="RL_Left"]')
block.set('style','fill:{}'.format(colors[646]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="RL_Right"]')
block.set('style','fill:{}'.format(colors[647]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="RM_Left"]')
block.set('style','fill:{}'.format(colors[648]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="RM_Right"]')
block.set('style','fill:{}'.format(colors[649]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="RN_Left"]')
block.set('style','fill:{}'.format(colors[650]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="RN_Right"]')
block.set('style','fill:{}'.format(colors[651]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="RO_Left"]')
block.set('style','fill:{}'.format(colors[652]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="RO_Right"]')
block.set('style','fill:{}'.format(colors[653]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="RPA_Left"]')
block.set('style','fill:{}'.format(colors[654]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="RPA_Right"]')
block.set('style','fill:{}'.format(colors[655]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="RPO_Left"]')
block.set('style','fill:{}'.format(colors[656]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="RPO_Right"]')
block.set('style','fill:{}'.format(colors[657]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="RR_Left"]')
block.set('style','fill:{}'.format(colors[658]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="RR_Right"]')
block.set('style','fill:{}'.format(colors[659]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="RSPagl_Left"]')
block.set('style','fill:{}'.format(colors[660]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="RSPagl_Right"]')
block.set('style','fill:{}'.format(colors[661]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="RSPd_Left"]')
block.set('style','fill:{}'.format(colors[662]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="RSPd_Right"]')
block.set('style','fill:{}'.format(colors[663]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="RSPv_Left"]')
block.set('style','fill:{}'.format(colors[664]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="RSPv_Right"]')
block.set('style','fill:{}'.format(colors[665]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="RSPv.a_Left"]')
block.set('style','fill:{}'.format(colors[666]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="RSPv.a_Right"]')
block.set('style','fill:{}'.format(colors[667]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="RSPv.b_c_Left"]')
block.set('style','fill:{}'.format(colors[668]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="RSPv.b_c_Right"]')
block.set('style','fill:{}'.format(colors[669]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="RT_Left"]')
block.set('style','fill:{}'.format(colors[670]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="RT_Right"]')
block.set('style','fill:{}'.format(colors[671]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="SAG_Left"]')
block.set('style','fill:{}'.format(colors[672]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="SAG_Right"]')
block.set('style','fill:{}'.format(colors[673]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="SBPV_Left"]')
block.set('style','fill:{}'.format(colors[674]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="SBPV_Right"]')
block.set('style','fill:{}'.format(colors[675]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="SC_Left"]')
block.set('style','fill:{}'.format(colors[676]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="SC_Right"]')
block.set('style','fill:{}'.format(colors[677]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="SCG_Left"]')
block.set('style','fill:{}'.format(colors[678]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="SCG_Right"]')
block.set('style','fill:{}'.format(colors[679]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="SCH_Left"]')
block.set('style','fill:{}'.format(colors[680]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="SCH_Right"]')
block.set('style','fill:{}'.format(colors[681]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="SF_Left"]')
block.set('style','fill:{}'.format(colors[682]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="SF_Right"]')
block.set('style','fill:{}'.format(colors[683]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="SFO_Left"]')
block.set('style','fill:{}'.format(colors[684]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="SFO_Right"]')
block.set('style','fill:{}'.format(colors[685]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="SG_Left"]')
block.set('style','fill:{}'.format(colors[686]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="SG_Right"]')
block.set('style','fill:{}'.format(colors[687]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="SGN_Left"]')
block.set('style','fill:{}'.format(colors[688]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="SGN_Right"]')
block.set('style','fill:{}'.format(colors[689]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="SH_Left"]')
block.set('style','fill:{}'.format(colors[690]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="SH_Right"]')
block.set('style','fill:{}'.format(colors[691]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="SI_Left"]')
block.set('style','fill:{}'.format(colors[692]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="SI_Right"]')
block.set('style','fill:{}'.format(colors[693]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="SIM_Left"]')
block.set('style','fill:{}'.format(colors[694]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="SIM_Right"]')
block.set('style','fill:{}'.format(colors[695]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="SLC_Left"]')
block.set('style','fill:{}'.format(colors[696]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="SLC_Right"]')
block.set('style','fill:{}'.format(colors[697]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="SLD_Left"]')
block.set('style','fill:{}'.format(colors[698]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="SLD_Right"]')
block.set('style','fill:{}'.format(colors[699]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="SMT_Left"]')
block.set('style','fill:{}'.format(colors[700]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="SMT_Right"]')
block.set('style','fill:{}'.format(colors[701]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="SNc_Left"]')
block.set('style','fill:{}'.format(colors[702]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="SNc_Right"]')
block.set('style','fill:{}'.format(colors[703]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="SNr_Left"]')
block.set('style','fill:{}'.format(colors[704]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="SNr_Right"]')
block.set('style','fill:{}'.format(colors[705]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="SO_Left"]')
block.set('style','fill:{}'.format(colors[706]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="SO_Right"]')
block.set('style','fill:{}'.format(colors[707]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="SOC_Left"]')
block.set('style','fill:{}'.format(colors[708]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="SOC_Right"]')
block.set('style','fill:{}'.format(colors[709]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="SPFm_Left"]')
block.set('style','fill:{}'.format(colors[710]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="SPFm_Right"]')
block.set('style','fill:{}'.format(colors[711]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="SPFp_Left"]')
block.set('style','fill:{}'.format(colors[712]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="SPFp_Right"]')
block.set('style','fill:{}'.format(colors[713]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="SPIV_Left"]')
block.set('style','fill:{}'.format(colors[714]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="SPIV_Right"]')
block.set('style','fill:{}'.format(colors[715]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="SPVC_Left"]')
block.set('style','fill:{}'.format(colors[716]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="SPVC_Right"]')
block.set('style','fill:{}'.format(colors[717]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="SPVI_Left"]')
block.set('style','fill:{}'.format(colors[718]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="SPVI_Right"]')
block.set('style','fill:{}'.format(colors[719]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="SPVO_Left"]')
block.set('style','fill:{}'.format(colors[720]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="SPVO_Right"]')
block.set('style','fill:{}'.format(colors[721]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="SRN_Left"]')
block.set('style','fill:{}'.format(colors[722]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="SRN_Right"]')
block.set('style','fill:{}'.format(colors[723]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="SSN_Left"]')
block.set('style','fill:{}'.format(colors[724]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="SSN_Right"]')
block.set('style','fill:{}'.format(colors[725]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="SSp_Left"]')
block.set('style','fill:{}'.format(colors[726]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="SSp_Right"]')
block.set('style','fill:{}'.format(colors[727]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="SSs_Left"]')
block.set('style','fill:{}'.format(colors[728]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="SSs_Right"]')
block.set('style','fill:{}'.format(colors[729]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="STN_Left"]')
block.set('style','fill:{}'.format(colors[730]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="STN_Right"]')
block.set('style','fill:{}'.format(colors[731]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="SUBd_Left"]')
block.set('style','fill:{}'.format(colors[732]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="SUBd_Right"]')
block.set('style','fill:{}'.format(colors[733]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="SUBv_Left"]')
block.set('style','fill:{}'.format(colors[734]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="SUBv_Right"]')
block.set('style','fill:{}'.format(colors[735]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="SUMl_Left"]')
block.set('style','fill:{}'.format(colors[736]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="SUMl_Right"]')
block.set('style','fill:{}'.format(colors[737]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="SUMm_Left"]')
block.set('style','fill:{}'.format(colors[738]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="SUMm_Right"]')
block.set('style','fill:{}'.format(colors[739]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="SUT_Left"]')
block.set('style','fill:{}'.format(colors[740]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="SUT_Right"]')
block.set('style','fill:{}'.format(colors[741]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="SUV_Left"]')
block.set('style','fill:{}'.format(colors[742]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="SUV_Right"]')
block.set('style','fill:{}'.format(colors[743]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="TEa_Left"]')
block.set('style','fill:{}'.format(colors[744]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="TEa_Right"]')
block.set('style','fill:{}'.format(colors[745]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="TM_Left"]')
block.set('style','fill:{}'.format(colors[746]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="TM_Right"]')
block.set('style','fill:{}'.format(colors[747]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="TR_Left"]')
block.set('style','fill:{}'.format(colors[748]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="TR_Right"]')
block.set('style','fill:{}'.format(colors[749]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="TRN_Left"]')
block.set('style','fill:{}'.format(colors[750]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="TRN_Right"]')
block.set('style','fill:{}'.format(colors[751]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="TRS_Left"]')
block.set('style','fill:{}'.format(colors[752]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="TRS_Right"]')
block.set('style','fill:{}'.format(colors[753]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="TTd_Left"]')
block.set('style','fill:{}'.format(colors[754]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="TTd_Right"]')
block.set('style','fill:{}'.format(colors[755]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="TTv_Left"]')
block.set('style','fill:{}'.format(colors[756]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="TTv_Right"]')
block.set('style','fill:{}'.format(colors[757]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="TU_Left"]')
block.set('style','fill:{}'.format(colors[758]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="TU_Right"]')
block.set('style','fill:{}'.format(colors[759]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="UVU_or_LIX_Left"]')
block.set('style','fill:{}'.format(colors[760]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="UVU_or_LIX_Right"]')
block.set('style','fill:{}'.format(colors[761]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="VAL_Left"]')
block.set('style','fill:{}'.format(colors[762]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="VAL_Right"]')
block.set('style','fill:{}'.format(colors[763]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="VCOa_Left"]')
block.set('style','fill:{}'.format(colors[764]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="VCOa_Right"]')
block.set('style','fill:{}'.format(colors[765]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="VCOp_Left"]')
block.set('style','fill:{}'.format(colors[766]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="VCOp_Right"]')
block.set('style','fill:{}'.format(colors[767]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="VHp_Left"]')
block.set('style','fill:{}'.format(colors[768]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="VHp_Right"]')
block.set('style','fill:{}'.format(colors[769]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="VI_Left"]')
block.set('style','fill:{}'.format(colors[770]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="VI_Right"]')
block.set('style','fill:{}'.format(colors[771]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="VII_Left"]')
block.set('style','fill:{}'.format(colors[772]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="VII_Right"]')
block.set('style','fill:{}'.format(colors[773]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="VISal_Left"]')
block.set('style','fill:{}'.format(colors[774]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="VISal_Right"]')
block.set('style','fill:{}'.format(colors[775]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="VISam_Left"]')
block.set('style','fill:{}'.format(colors[776]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="VISam_Right"]')
block.set('style','fill:{}'.format(colors[777]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="VISC_Left"]')
block.set('style','fill:{}'.format(colors[778]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="VISC_Right"]')
block.set('style','fill:{}'.format(colors[779]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="VISli_Left"]')
block.set('style','fill:{}'.format(colors[780]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="VISli_Right"]')
block.set('style','fill:{}'.format(colors[781]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="VISll_Left"]')
block.set('style','fill:{}'.format(colors[782]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="VISll_Right"]')
block.set('style','fill:{}'.format(colors[783]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="VISlla_Left"]')
block.set('style','fill:{}'.format(colors[784]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="VISlla_Right"]')
block.set('style','fill:{}'.format(colors[785]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="VISlm_Left"]')
block.set('style','fill:{}'.format(colors[786]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="VISlm_Right"]')
block.set('style','fill:{}'.format(colors[787]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="VISp_Left"]')
block.set('style','fill:{}'.format(colors[788]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="VISp_Right"]')
block.set('style','fill:{}'.format(colors[789]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="VISpl_Left"]')
block.set('style','fill:{}'.format(colors[790]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="VISpl_Right"]')
block.set('style','fill:{}'.format(colors[791]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="VISpm_Left"]')
block.set('style','fill:{}'.format(colors[792]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="VISpm_Right"]')
block.set('style','fill:{}'.format(colors[793]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="VISrl_Left"]')
block.set('style','fill:{}'.format(colors[794]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="VISrl_Right"]')
block.set('style','fill:{}'.format(colors[795]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="VLP_Left"]')
block.set('style','fill:{}'.format(colors[796]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="VLP_Right"]')
block.set('style','fill:{}'.format(colors[797]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="VM_Left"]')
block.set('style','fill:{}'.format(colors[798]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="VM_Right"]')
block.set('style','fill:{}'.format(colors[799]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="Vma_Left"]')
block.set('style','fill:{}'.format(colors[800]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="Vma_Right"]')
block.set('style','fill:{}'.format(colors[801]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="VMHa_Left"]')
block.set('style','fill:{}'.format(colors[802]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="VMHa_Right"]')
block.set('style','fill:{}'.format(colors[803]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="VMHc_Left"]')
block.set('style','fill:{}'.format(colors[804]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="VMHc_Right"]')
block.set('style','fill:{}'.format(colors[805]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="VMHdm_Left"]')
block.set('style','fill:{}'.format(colors[806]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="VMHdm_Right"]')
block.set('style','fill:{}'.format(colors[807]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="VMHvl_Left"]')
block.set('style','fill:{}'.format(colors[808]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="VMHvl_Right"]')
block.set('style','fill:{}'.format(colors[809]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="Vpc_Left"]')
block.set('style','fill:{}'.format(colors[810]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="Vpc_Right"]')
block.set('style','fill:{}'.format(colors[811]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="VPLpc_Left"]')
block.set('style','fill:{}'.format(colors[812]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="VPLpc_Right"]')
block.set('style','fill:{}'.format(colors[813]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="VPLpr_Left"]')
block.set('style','fill:{}'.format(colors[814]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="VPLpr_Right"]')
block.set('style','fill:{}'.format(colors[815]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="VPMpc_Left"]')
block.set('style','fill:{}'.format(colors[816]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="VPMpc_Right"]')
block.set('style','fill:{}'.format(colors[817]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="VPMpr_Left"]')
block.set('style','fill:{}'.format(colors[818]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="VPMpr_Right"]')
block.set('style','fill:{}'.format(colors[819]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="VTA_Left"]')
block.set('style','fill:{}'.format(colors[820]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="VTA_Right"]')
block.set('style','fill:{}'.format(colors[821]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="VTN_Left"]')
block.set('style','fill:{}'.format(colors[822]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="VTN_Right"]')
block.set('style','fill:{}'.format(colors[823]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="x_Left"]')
block.set('style','fill:{}'.format(colors[824]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="x_Right"]')
block.set('style','fill:{}'.format(colors[825]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="XI_Left"]')
block.set('style','fill:{}'.format(colors[826]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="XI_Right"]')
block.set('style','fill:{}'.format(colors[827]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="XII_Left"]')
block.set('style','fill:{}'.format(colors[828]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="XII_Right"]')
block.set('style','fill:{}'.format(colors[829]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="y_Left"]')
block.set('style','fill:{}'.format(colors[830]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="y_Right"]')
block.set('style','fill:{}'.format(colors[831]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="z_Left"]')
block.set('style','fill:{}'.format(colors[832]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="z_Right"]')
block.set('style','fill:{}'.format(colors[833]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="ZI_Left"]')
block.set('style','fill:{}'.format(colors[834]))
block = root.find('{http://www.w3.org/2000/svg}path[@class="ZI_Right"]')
block.set('style','fill:{}'.format(colors[835]))

tree.write('ex.svg')
